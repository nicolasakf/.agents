# %% [markdown]
# # Workspace Explorer

# %% [markdown]
# ## Description
# Explores the local workspace filesystem, analyzes project structure, searches for files or text, and summarizes the workspace layout. Use when you need to understand the project directory structure, locate specific files or configurations, find where variables/functions are defined, or get a general lay of the land in an unfamiliar repository.

# %% [markdown]
# ## System Prompt
# You are an autonomous workspace explorer sub-agent. Your goal is to rapidly and accurately comprehend the structure, contents, and purpose of the local project directory.
#
# **Expected Input:**
# The parent agent will provide a description of what to look for (e.g., 'summarize the project structure', 'find where the database connection is established', or 'list all markdown files').
#
# **Capabilities & Best Practices:**
# 1. **Python Utilities First:** Use the `WorkspaceExplorer` Python class provided in the scratchpad cells below. It is designed to safely summarize large directories, respect common ignore patterns (like `node_modules` or `.git`), and avoid context-window overflows.
# 2. **Avoid Massive Outputs:** Never run unrestricted `find .` or `tree` commands, and avoid printing entire large files. Always use depth limits (`max_depth`) and read snippets.
# 3. **Fallback to Bash:** Use the `bash` tool (with `rg`, `fd`, `find`) if you need complex command-line searches not covered by the Python utilities.
# 4. **Read Files:** Use the `read_file` tool to inspect the exact contents of files once you locate them.
# 5. **Read-Only:** You are strictly read-only. Do not modify, move, or delete files.
#
# **Final Output:**
# Return a concise, structured markdown summary to the parent agent. Include the most relevant file paths, a high-level project architecture, and direct answers to the parent's specific queries.

# %%
import os
print('This is your current working directoy:', os.getcwd())
# Out:
# This is your current working directoy: /Users/nicolasfonteyne/.agents/subagents

# %%
# Reusable Workspace Explorer Python Utility
import re
from pathlib import Path
from collections import Counter
import json

class WorkspaceExplorer:
    def __init__(self, root="."):
        self.root = Path(root).resolve()
        # Common directories and files to ignore to keep context clean
        self.ignore_dirs = {'.git', 'node_modules', 'venv', '.venv', 'env', '__pycache__', '.pytest_cache', 'build', 'dist', '.next', 'coverage', '.idea', '.vscode'}
        self.ignore_exts = {'.pyc', '.pdf', '.png', '.jpg', '.jpeg', '.gif', '.zip', '.tar', '.gz', '.mp4', '.sqlite3', '.db', '.DS_Store'}

    def _is_ignored(self, path: Path) -> bool:
        if path.name in self.ignore_dirs:
            return True
        if path.suffix.lower() in self.ignore_exts:
            return True
        return False

    def get_tree(self, max_depth=2) -> str:
        """Generates a clean tree view of the directory up to max_depth."""
        tree_str = []
        
        def walk(current_path, prefix="", depth=0):
            if depth > max_depth:
                return
            try:
                entries = sorted(list(current_path.iterdir()), key=lambda x: (not x.is_dir(), x.name))
            except PermissionError:
                return
                
            entries = [e for e in entries if not self._is_ignored(e) and not e.name.startswith('.')]
            
            for i, entry in enumerate(entries):
                is_last = (i == len(entries) - 1)
                connector = "└── " if is_last else "├── "
                tree_str.append(f"{prefix}{connector}{entry.name}{'/' if entry.is_dir() else ''}")
                
                if entry.is_dir():
                    extension = "    " if is_last else "│   "
                    walk(entry, prefix + extension, depth + 1)
                    
        tree_str.append(f"📂 {self.root.name}/")
        walk(self.root)
        return "\n".join(tree_str)

    def get_stats(self) -> dict:
        """Returns a dictionary of file counts by extension and total size."""
        ext_counts = Counter()
        total_size = 0
        file_count = 0
        
        for dirpath, dirnames, filenames in os.walk(self.root):
            # Modify dirnames in-place to skip ignored directories
            dirnames[:] = [d for d in dirnames if d not in self.ignore_dirs and not d.startswith('.')]
            
            for f in filenames:
                p = Path(dirpath) / f
                if self._is_ignored(p) or f.startswith('.'):
                    continue
                ext = p.suffix.lower() or 'no_extension'
                ext_counts[ext] += 1
                file_count += 1
                try:
                    total_size += p.stat().st_size
                except OSError:
                    pass
                    
        return {
            "total_files": file_count,
            "total_size_mb": round(total_size / (1024 * 1024), 2),
            "top_extensions": dict(ext_counts.most_common(10))
        }
        
    def find_content(self, pattern: str, max_results=15) -> list:
        """Searches for a regex pattern in files, returning a list of matched lines."""
        matches = []
        try:
            regex = re.compile(pattern, re.IGNORECASE)
        except re.error:
            return ["Invalid regex pattern"]
            
        for dirpath, dirnames, filenames in os.walk(self.root):
            dirnames[:] = [d for d in dirnames if d not in self.ignore_dirs and not d.startswith('.')]
            
            for f in filenames:
                if len(matches) >= max_results:
                    return matches
                    
                p = Path(dirpath) / f
                if self._is_ignored(p) or f.startswith('.'):
                    continue
                    
                try:
                    with open(p, 'r', encoding='utf-8', errors='ignore') as file:
                        for line_no, line in enumerate(file, 1):
                            if regex.search(line):
                                matches.append(f"{p.relative_to(self.root)}:{line_no}: {line.strip()[:120]}")
                                if len(matches) >= max_results:
                                    break
                except Exception:
                    pass
        return matches

# %%
# Run this cell to instantly get a high-level overview of the project structure and stats
explorer = WorkspaceExplorer('../../Github_nicolasakf/Orion')

print("=== WORKSPACE TREE (Depth=2) ===")
print(explorer.get_tree(max_depth=2))

print("\n=== WORKSPACE STATS ===")
print(json.dumps(explorer.get_stats(), indent=2))

# print("\n=== EXAMPLE SEARCH ===")
# for match in explorer.find_content(r"database_url", max_results=5):
#     print(match)
# Out:
# === WORKSPACE TREE (Depth=2) ===
# 📂 nicolasfonteyne/
# ├── Applications/
# │   ├── Chrome Apps.localized/
# │   │   └── Icon
# │   └── Claude Code URL Handler.app/
# │       └── Contents/
# ├── Desktop/
# ├── Documents/
# │   ├── Bibs Photos/
# │   │   ├── 100LEICA/
# │   │   ├── 101LEICA/
# │   │   ├── 102LEICA/
# │   │   └── 103LEICA/
# │   ├── Codex/
# │   │   ├── 2026-05-02/
# │   │   └── 2026-05-05/
# │   ├── MOD1/
# │   │   ├── OneDrive_1_10-9-2025/
# │   │   ├── ACC7800 BETA-X FSR#1 - Step-by-Step Guide (Fall 2025).pptx
# │   │   ├── ACC7800 RCP B - BSE Template (Fall 2025).xlsx
# │   │   ├── Clipy_1.2.1.dmg
# │   │   ├── Coke_Pepsi_Health Check.xlsx
# │   │   ├── EPS_7578-A55_-_RAISING_MONEY-VC.xlsx
# │   │   ├── FSR BetaX Assignment 2.pptx
# │   │   ├── MOB 7800 Sample Action Plan.docx
# │   │   ├── MOB Group Reflection.pptx
# │   │   ├── Parking Fees.xlsx
# │   │   ├── Parking.xlsx
# │   │   ├── Reddit-Logo.wine.svg
# │   │   ├── Rocket_Pitch_Application_2025 v3.docx
# │   │   ├── SharkNinja Questions.docx
# │   │   ├── Tessei Speech.pages
# │   │   ├── The Accountant Case (1).docx
# │   │   ├── The Accountant Case.docx
# │   │   └── Waltham Kayak - Cash Flow Practice Problem (Fall 2025).docx
# │   ├── Screen Studio Background Audio/
# │   ├── Screen Studio Presets/
# │   └── Zoom/
# ├── Downloads/
# │   ├── External Documents/
# │   │   ├── BofA/
# │   │   ├── Data Providers/
# │   │   ├── GS EFI/
# │   │   ├── PB/
# │   │   ├── Pricing/
# │   │   ├── Trading/
# │   │   ├── dask-worker-space/
# │   │   ├── IBOVE Composition.xlsx
# │   │   └── Job Description.docx
# │   ├── Inter-4.1/
# │   │   ├── extras/
# │   │   ├── web/
# │   │   ├── Inter.ttc
# │   │   ├── InterVariable-Italic.ttf
# │   │   ├── InterVariable.ttf
# │   │   ├── LICENSE.txt
# │   │   └── help.txt
# │   ├── Orbitron/
# │   │   ├── static/
# │   │   ├── OFL.txt
# │   │   ├── Orbitron-VariableFont_wght.ttf
# │   │   └── README.txt
# │   ├── Private & Shared/
# │   │   └── Competition 2a90df0f051a809f8c94cdf4dff41809.md
# │   ├── Private & Shared 2/
# │   │   ├── Product Roadmap 20e0df0f051a80be83fef30a277a366a.csv
# │   │   └── Product Roadmap 20e0df0f051a80be83fef30a277a366a_all.csv
# │   ├── Private & Shared 3/
# │   │   ├── Product Roadmap/
# │   │   ├── Product Roadmap 20e0df0f051a80be83fef30a277a366a.csv
# │   │   └── Product Roadmap 20e0df0f051a80be83fef30a277a366a_all.csv
# │   ├── Private & Shared 4/
# │   │   ├── Product Roadmap/
# │   │   └── Product Roadmap 20e0df0f051a80be83fef30a277a366a.csv
# │   ├── StudyA/
# │   │   └── StudyA.xlsx
# │   ├── StudyH/
# │   │   └── StudyH.xlsx
# │   ├── StudyI/
# │   │   └── StudyI.xlsx
# │   ├── course_files_export/
# │   │   ├── S.01 Introduction to Marketing/
# │   │   ├── S.02 Market Research I/
# │   │   ├── S.03 Market Research II & Consumer Decision Making I/
# │   │   ├── S.04 Consumer Decision Making II/
# │   │   ├── S.05 Segmentation & Targeting I/
# │   │   ├── ~Final Exam/
# │   │   └── ~Syllabus/
# │   ├── course_files_export (1)/
# │   │   ├── Scripts/
# │   │   ├── Slides/
# │   │   ├── course_image/
# │   │   ├── Learning Goals.docx
# │   │   └── ensemble_nnet.R
# │   ├── kaggle-survey-2022/
# │   │   ├── Supplementary Data/
# │   │   └── kaggle_survey_2022_responses.csv
# │   ├── 521703-XLS-ENG.xlsx
# │   ├── AI Assistant for Jupyter Notebooks.md
# │   ├── BA Exam Handout-2025 (1).xlsx
# │   ├── BA Exam Handout-2025.xlsx
# │   ├── BA Milestone 2 (1).docx
# │   ├── BA Milestone 2.docx
# │   ├── BAMA 05 Feedback.docx
# │   ├── BCE Client Overview_Prabhakar Processors_.pptx
# │   ├── BETA Challenge (1).pptx
# │   ├── BETA Challenge.pptx
# │   ├── Blue Arpon Assignment.docx
# │   ├── Bond Stock & firm Valuation Template.xlsx
# │   ├── Book5.xlsx
# │   ├── CBOE Volatility Index Historical Data.csv
# │   ├── CLAUDE.md
# │   ├── Capital Budgeting Template.xlsx
# │   ├── Claude.dmg
# │   ├── Codex (1).dmg
# │   ├── Codex (2).dmg
# │   ├── Codex.dmg
# │   ├── Daily Crunch Marketing Final.pptx
# │   ├── Daily Crunch_Data File.xlsx
# │   ├── Decision Analysis Case - Samsung - Group 5 (1).docx
# │   ├── Decision Analysis Case - Samsung - Group 5.docx
# │   ├── Discord.dmg
# │   ├── Drager Addendum Exhibits-2.xlsx
# │   ├── Drager_Analysis template.xlsx
# │   ├── Drager_Analysis-Template - Nov 2023 (1).xlsx
# │   ├── Drager_Analysis-Template - Nov 2023.xlsx
# │   ├── EPS7578 Syllabus LaPoint Spring 2025.doc
# │   ├── Executive Summary Reduced.docx
# │   ├── Executive Summary.docx
# │   ├── External Documents.rar
# │   ├── Final Case - Newmont Mining.docx
# │   ├── Financing CLASS SCHEDULE  Spring 2026-2.docx
# │   ├── Flow-v1.4.303.dmg
# │   ├── Genius Bar Reservation.ics
# │   ├── Grade Breakdown and Recommendations (1).docx
# │   ├── Group 6 VC_Negotiation Reflection.docx
# │   ├── Hanson_Ski_Exhibits.xlsx
# │   ├── IMG_4778.HEIC
# │   ├── IMG_4781.HEIC
# │   ├── IMG_4782.HEIC
# │   ├── IMG_5095.heic
# │   ├── IMG_5134.HEIC
# │   ├── IMG_5135.HEIC
# │   ├── IMG_5136.HEIC
# │   ├── IMG_5137.HEIC
# │   ├── IMG_5138.HEIC
# │   ├── IMG_5139.HEIC
# │   ├── IMG_5140.HEIC
# │   ├── IMG_5160.HEIC
# │   ├── IMG_5398.HEIC
# │   ├── IMG_5399.HEIC
# │   ├── MKT7800 Fall25 Academic Code Cover Sheet.docx
# │   ├── McDonald Valuation Exercise DCF Approach template.xlsx
# │   ├── Natureview Farm Case.docx
# │   ├── Newmont Mining Co BA-2025.docx
# │   ├── Nicolas Fonteyne Paper.docx
# │   ├── Onnie Jewellers _ Nicolas Fonteyne+Adam Rogers+Bianca Kolberg.xlsx
# │   ├── Onnie Jewellers_template-1.xlsx
# │   ├── Onnie Jewellers_template.xlsx
# │   ├── Onnie online_purchase_durations.csv
# │   ├── Pigeon.pptx
# │   ├── Polymarket-Transaction-History-Fri Dec 19 2025 16_56_33 GMT-0300 (Brasilia Standard Time).csv
# │   ├── Polymarket-Transaction-History-Sun Jan 18 2026 21_10_09 GMT-0500 (Eastern Standard Time).csv
# │   ├── Problem Solving Design Plan Template-1.pptx
# │   ├── REPOS.rar
# │   ├── RStudio-2026.01.0-392.dmg
# │   ├── Risk & Return Worksbook.xlsx
# │   ├── S&P 500 Historical Data.csv
# │   ├── S4.2 Blue Apron Data Set.Experiments.xlsx
# │   ├── S5.4 Customer Cluster Analysis.xlsx
# │   ├── Scope of Work- Prabhakar-Processors.docx
# │   ├── Screen Recording 2026-04-14 at 7.30.17 PM.mov
# │   ├── Seraf Toolkit Model Deal Terms Expectations Summary Memo.xlsx
# │   ├── Session 3 Relative Valuation Templates-1.xlsx
# │   ├── Sharkninja Stock Price History.csv
# │   ├── Slack-4.47.59-macOS.dmg
# │   ├── Sneaker Template_update-1.xlsx
# │   ├── Stremio_arm64.dmg
# │   ├── Study 1.csv
# │   ├── TVM Excel Workbook-4.xlsx
# │   ├── Thiago_Costa.vcf
# │   ├── Trashi Financial Assumptions.xlsx
# │   ├── Trashi Financials.xlsx
# │   ├── Walmart Exercise dividend approach_template.xlsx
# │   ├── canvas_export.xlsx
# │   ├── claude-color.svg
# │   ├── claude.svg
# │   ├── comet_latest.dmg
# │   ├── create_github_issues.sh
# │   ├── create_github_issues_4.sh
# │   ├── cursor_web_search_fetch_tool.md
# │   ├── env.example
# │   ├── export-0x8bb3ce509a71eacde45ebf6a2f50d004eaef37dc.csv
# │   ├── gemini.svg
# │   ├── install.sh
# │   ├── loader-pinwheel.svg
# │   ├── m42-PI-alt2WM.webp
# │   ├── npm_recovery_codes.txt
# │   ├── openai-svgrepo-com.svg
# │   ├── paint_pen_proforma.html
# │   ├── polymarket-483214-ce030536c8b5.json
# │   ├── polymarket-price-data-01-10-2025-01-01-2026-1767288531573.csv
# │   ├── team_Prabhakar_Draft Scope of Work_Feb _3rd.docx
# │   ├── transcsv.csv
# │   ├── usage-events-2026-04-04.csv
# │   ├── xai.svg
# │   ├── ~$a.docx
# │   └── ~$intPen_Acquisition_WriteUp.docx
# ├── Github_nicolasakf/
# │   ├── Archived/
# │   │   └── Orion-website/
# │   ├── Babson/
# │   │   └── canvas_financing_answer.ipynb
# │   ├── CLAUDE-CODE-SYSTEM-PROMPT/
# │   │   ├── CC-SYS-PROMPT-04-14-26-1.md
# │   │   ├── CC-SYS-PROMPT-04-14-26-2.md
# │   │   ├── CC-SYS-PROMPT-04-14-26-3.md
# │   │   └── README.md
# │   ├── Canvas-Toolkit-for-Babson-MBA-Students/
# │   │   ├── canvas_toolkit/
# │   │   ├── canvas_toolkit.egg-info/
# │   │   ├── examples/
# │   │   ├── tests/
# │   │   ├── CONTRIBUTING.md
# │   │   ├── FILTER_IMPLEMENTATION_COMPLETE.md
# │   │   ├── IMPROVEMENTS_COMPLETED.md
# │   │   ├── IMPROVEMENT_PLAN.md
# │   │   ├── LICENSE
# │   │   ├── PHASE2_5_IMPLEMENTATION_SUMMARY.md
# │   │   ├── PHASE2_TESTING_RESULTS.md
# │   │   ├── QUICK_START.md
# │   │   ├── README.md
# │   │   ├── SECURITY.md
# │   │   ├── SETUP.md
# │   │   ├── canvas_export.xlsx
# │   │   ├── canvas_toolkit.py
# │   │   ├── install-canvas-toolkit.bat
# │   │   ├── requirements.txt
# │   │   ├── run-canvas-toolkit.bat
# │   │   ├── setup.py
# │   │   ├── test_filter.py
# │   │   ├── test_phase2.py
# │   │   └── test_phase2_5.py
# │   ├── Orion/
# │   │   ├── app/
# │   │   ├── components/
# │   │   ├── contexts/
# │   │   ├── docs/
# │   │   ├── hooks/
# │   │   ├── lib/
# │   │   ├── logs/
# │   │   ├── private/
# │   │   ├── public/
# │   │   ├── scripts/
# │   │   ├── supabase/
# │   │   ├── types/
# │   │   ├── AGENTS.md
# │   │   ├── CLAUDE.md
# │   │   ├── README.md
# │   │   ├── components.json
# │   │   ├── middleware.ts
# │   │   ├── next-env.d.ts
# │   │   ├── next.config.mjs
# │   │   ├── package-lock.json
# │   │   ├── package.json
# │   │   ├── postcss.config.mjs
# │   │   ├── tailwind.config.ts
# │   │   ├── tsconfig.json
# │   │   └── tsconfig.tsbuildinfo
# │   ├── Orion-demo/
# │   │   ├── sales.xlsx
# │   │   └── streaming_long_cells_sample.ipynb
# │   ├── Orion-research/
# │   │   ├── Archived/
# │   │   └── polymarket_disputed_markets.ipynb
# │   ├── Orion-website/
# │   │   ├── app/
# │   │   ├── components/
# │   │   ├── hooks/
# │   │   ├── lib/
# │   │   ├── public/
# │   │   ├── styles/
# │   │   ├── components.json
# │   │   ├── next-env.d.ts
# │   │   ├── next.config.mjs
# │   │   ├── package-lock.json
# │   │   ├── package.json
# │   │   ├── pnpm-lock.yaml
# │   │   ├── postcss.config.mjs
# │   │   ├── tailwind.config.ts
# │   │   ├── tsconfig.json
# │   │   └── tsconfig.tsbuildinfo
# │   ├── QTM7571/
# │   │   ├── Project/
# │   │   ├── catboost_info/
# │   │   ├── data/
# │   │   ├── input/
# │   │   ├── output/
# │   │   ├── QTM7571.Rproj
# │   │   ├── bird_population_100y_analysis.ipynb
# │   │   ├── boston_house_prices_model.ipynb
# │   │   ├── distancias_fabio_fev.ipynb
# │   │   ├── distancias_fev2026.ipynb
# │   │   ├── ebay_auction_classification.ipynb
# │   │   ├── eda_amtrak.ipynb
# │   │   ├── equity_volatility_modeling.ipynb
# │   │   ├── expectancy_fertility_eda.ipynb
# │   │   ├── gold_price_prediction.ipynb
# │   │   ├── gold_weekly_price_model.ipynb
# │   │   ├── hclust_utilities.R
# │   │   ├── heart_risk_analysis.ipynb
# │   │   ├── hmw1.R
# │   │   ├── hmw2.R
# │   │   ├── hmw3.R
# │   │   ├── hmw4.R
# │   │   ├── hmw5.R
# │   │   ├── hmw6.R
# │   │   ├── hmw8.R
# │   │   ├── house_prices_kaggle.ipynb
# │   │   ├── hw_clustering.R
# │   │   ├── kmeans_expectancy_fertility.R
# │   │   ├── nyc_bike_matplotlib_plots.ipynb
# │   │   ├── openclaw_cost_comparison.ipynb
# │   │   ├── session1.R
# │   │   ├── session11.R
# │   │   ├── session2.R
# │   │   ├── session3.R
# │   │   ├── session4.R
# │   │   ├── session5.R
# │   │   ├── session6.R
# │   │   ├── session7.R
# │   │   ├── session8.R
# │   │   ├── session9.R
# │   │   ├── spy_data.csv
# │   │   ├── submission.csv
# │   │   ├── test_notebook.ipynb
# │   │   ├── toyota_eda.ipynb
# │   │   ├── toyota_tree_hw.ipynb
# │   │   ├── universal_bank_analysis.ipynb
# │   │   ├── untitled.ipynb
# │   │   └── yelp_data_cleaning.ipynb
# │   ├── ai/
# │   │   ├── assets/
# │   │   ├── content/
# │   │   ├── contributing/
# │   │   ├── examples/
# │   │   ├── packages/
# │   │   ├── skills/
# │   │   ├── tools/
# │   │   ├── AGENTS.md
# │   │   ├── CHANGELOG.md
# │   │   ├── CLAUDE.md
# │   │   ├── CODE_OF_CONDUCT.md
# │   │   ├── CONTRIBUTING.md
# │   │   ├── LICENSE
# │   │   ├── README.md
# │   │   ├── package.json
# │   │   ├── pnpm-lock.yaml
# │   │   ├── pnpm-workspace.yaml
# │   │   ├── socket.yaml
# │   │   ├── tsconfig.json
# │   │   ├── tsconfig.with-examples.json
# │   │   └── turbo.json
# │   ├── arctic/
# │   │   ├── arctic/
# │   │   ├── benchmarks/
# │   │   ├── docs/
# │   │   ├── howtos/
# │   │   ├── logo/
# │   │   ├── tests/
# │   │   ├── CHANGES.md
# │   │   ├── LICENSE
# │   │   ├── README.md
# │   │   ├── asv.conf.json
# │   │   ├── benchmarks.md
# │   │   ├── mkdocs.yml
# │   │   ├── setup.cfg
# │   │   └── setup.py
# │   ├── awesome-notebooks/
# │   │   ├── AI for Work/
# │   │   ├── AWS/
# │   │   ├── Abstract API/
# │   │   ├── Advertools/
# │   │   ├── Affinity/
# │   │   ├── Agicap/
# │   │   ├── Airtable/
# │   │   ├── Algolia/
# │   │   ├── AlphaVantage/
# │   │   ├── Anthropic/
# │   │   ├── Appwrite/
# │   │   ├── Azure Blob Storage/
# │   │   ├── Azure Machine Learning/
# │   │   ├── Bazimo/
# │   │   ├── BeautifulSoup/
# │   │   ├── BigQuery/
# │   │   ├── Bitly/
# │   │   ├── Boursorama/
# │   │   ├── Brevo/
# │   │   ├── Bubble/
# │   │   ├── Buffer/
# │   │   ├── CCXT/
# │   │   ├── Canny/
# │   │   ├── Celestrak/
# │   │   ├── Cityfalcon/
# │   │   ├── Clockify/
# │   │   ├── Cloud Mercato/
# │   │   ├── Creditsafe/
# │   │   ├── D-Tale/
# │   │   ├── Dash/
# │   │   ├── Dask/
# │   │   ├── Data.gouv.fr/
# │   │   ├── Datetime/
# │   │   ├── Deepl/
# │   │   ├── Draft Kings/
# │   │   ├── EM-DAT/
# │   │   ├── Elasticsearch/
# │   │   ├── Excel/
# │   │   ├── FAO/
# │   │   ├── FEC/
# │   │   ├── FED/
# │   │   ├── FTP/
# │   │   ├── Faker/
# │   │   ├── Folium/
# │   │   ├── Forecast/
# │   │   ├── Formant/
# │   │   ├── Geopy/
# │   │   ├── GitHub/
# │   │   ├── Gmail/
# │   │   ├── Google Analytics/
# │   │   ├── Google Calendar/
# │   │   ├── Google Docs/
# │   │   ├── Google Drive/
# │   │   ├── Google Gemini/
# │   │   ├── Google Maps/
# │   │   ├── Google Search/
# │   │   ├── Google Sheets/
# │   │   ├── Google Slides/
# │   │   ├── HTML/
# │   │   ├── Harvest/
# │   │   ├── Healthchecks/
# │   │   ├── HubSpot/
# │   │   ├── Hugging Face/
# │   │   ├── Hunter.io/
# │   │   ├── IFTTT/
# │   │   ├── IMDB/
# │   │   ├── INPI/
# │   │   ├── IPyWidgets/
# │   │   ├── IPython/
# │   │   ├── IUCN/
# │   │   ├── ImagineAPI/
# │   │   ├── Insee/
# │   │   ├── Instagram/
# │   │   ├── Integromat/
# │   │   ├── JSON/
# │   │   ├── Johns Hopkins/
# │   │   ├── Jupyter/
# │   │   ├── Jupyter Notebooks/
# │   │   ├── Kaggle/
# │   │   ├── Knative/
# │   │   ├── LangChain/
# │   │   ├── LeFigaro/
# │   │   ├── LinkedIn/
# │   │   ├── LinkedIn Sales Navigator/
# │   │   ├── LlamaIndex/
# │   │   ├── Matplotlib/
# │   │   ├── Medium/
# │   │   ├── Mercury/
# │   │   ├── Meta/
# │   │   ├── Metrics Store/
# │   │   ├── Microsoft Teams/
# │   │   ├── Microsoft Word/
# │   │   ├── Mixpanel/
# │   │   ├── MongoDB/
# │   │   ├── MoviePy/
# │   │   ├── MySQL/
# │   │   ├── NASA/
# │   │   ├── Naas/
# │   │   ├── Naas API/
# │   │   ├── Naas Auth/
# │   │   ├── Naas Chat Plugin/
# │   │   ├── Naas Credits/
# │   │   ├── Naas Dashboard/
# │   │   ├── Neo/
# │   │   ├── Neo4j/
# │   │   ├── News API/
# │   │   ├── Notion/
# │   │   ├── OS/
# │   │   ├── OWID/
# │   │   ├── OpenAI/
# │   │   ├── OpenAlex/
# │   │   ├── OpenBB/
# │   │   ├── OpenPIV/
# │   │   ├── OpenWeatherMap/
# │   │   ├── OwnCloud/
# │   │   ├── PDF/
# │   │   ├── Pandas/
# │   │   ├── Pandasql/
# │   │   ├── Panel/
# │   │   ├── Pappers/
# │   │   ├── Pennylane/
# │   │   ├── Pillow/
# │   │   ├── Pipedrive/
# │   │   ├── Plaid/
# │   │   ├── Plotly/
# │   │   ├── Polars/
# │   │   ├── PostgresSQL/
# │   │   ├── PowerPoint/
# │   │   ├── PyCaret/
# │   │   ├── PyGWalker/
# │   │   ├── PyPI/
# │   │   ├── Python/
# │   │   ├── Pyvis/
# │   │   ├── Qdrant/
# │   │   ├── Qonto/
# │   │   ├── Quandl/
# │   │   ├── Reddit/
# │   │   ├── Redshift/
# │   │   ├── RegEx/
# │   │   ├── Remoteok/
# │   │   ├── Remotive/
# │   │   ├── Request/
# │   │   ├── SAP-HANA/
# │   │   ├── SEON/
# │   │   ├── SQLite/
# │   │   ├── SWIFT/
# │   │   ├── SendGrid/
# │   │   ├── Sendinblue/
# │   │   ├── SharePoint/
# │   │   ├── Shutterstock/
# │   │   ├── Slack/
# │   │   ├── Snowflake/
# │   │   ├── Societe.com/
# │   │   ├── Spotify/
# │   │   ├── Stabilty AI/
# │   │   ├── Stable Diffusion/
# │   │   ├── Streamlit/
# │   │   ├── Stripe/
# │   │   ├── Supabase/
# │   │   ├── Telegram/
# │   │   ├── Text/
# │   │   ├── Thinkific/
# │   │   ├── TikTok/
# │   │   ├── Trello/
# │   │   ├── Twilio/
# │   │   ├── Twitter/
# │   │   ├── Typeform/
# │   │   ├── US Bureau of Labor Statistics/
# │   │   ├── Vizzu/
# │   │   ├── WAQI/
# │   │   ├── WSR/
# │   │   ├── WhatsApp/
# │   │   ├── Wikipedia/
# │   │   ├── WindsorAI/
# │   │   ├── WorldBank/
# │   │   ├── Worldometer/
# │   │   ├── XGBoost/
# │   │   ├── XML/
# │   │   ├── YahooFinance/
# │   │   ├── YouTube/
# │   │   ├── ZIP/
# │   │   ├── Zapier/
# │   │   ├── ZeroBounce/
# │   │   ├── gTTS/
# │   │   ├── spaCy/
# │   │   ├── CONTRIBUTING.md
# │   │   ├── LICENSE
# │   │   ├── Makefile
# │   │   ├── README.md
# │   │   ├── README_template.md
# │   │   ├── _config.yml
# │   │   ├── generate_certificate.py
# │   │   ├── generate_readme.ipynb
# │   │   ├── template.ipynb
# │   │   └── templates.json
# │   ├── boldr-web/
# │   │   ├── prisma/
# │   │   ├── src/
# │   │   ├── Buildfile
# │   │   ├── Dockerfile
# │   │   ├── Procfile
# │   │   ├── README.md
# │   │   ├── dockerignore
# │   │   ├── eslint.config.mjs
# │   │   ├── package-lock.json
# │   │   ├── package.json
# │   │   ├── run.sh
# │   │   ├── swagger.yml
# │   │   ├── tsconfig.json
# │   │   └── vitest.config.ts
# │   ├── btc-updown-bot/
# │   │   ├── src/
# │   │   ├── README.md
# │   │   ├── main.py
# │   │   ├── pyproject.toml
# │   │   └── uv.lock
# │   ├── claude-code/
# │   │   ├── assistant/
# │   │   ├── bootstrap/
# │   │   ├── bridge/
# │   │   ├── buddy/
# │   │   ├── cli/
# │   │   ├── commands/
# │   │   ├── components/
# │   │   ├── constants/
# │   │   ├── context/
# │   │   ├── coordinator/
# │   │   ├── entrypoints/
# │   │   ├── hooks/
# │   │   ├── ink/
# │   │   ├── keybindings/
# │   │   ├── memdir/
# │   │   ├── migrations/
# │   │   ├── moreright/
# │   │   ├── native-ts/
# │   │   ├── outputStyles/
# │   │   ├── plugins/
# │   │   ├── query/
# │   │   ├── remote/
# │   │   ├── schemas/
# │   │   ├── screens/
# │   │   ├── server/
# │   │   ├── services/
# │   │   ├── skills/
# │   │   ├── state/
# │   │   ├── tasks/
# │   │   ├── tools/
# │   │   ├── types/
# │   │   ├── upstreamproxy/
# │   │   ├── utils/
# │   │   ├── vim/
# │   │   ├── voice/
# │   │   ├── ARCHITECTURE.md
# │   │   ├── QueryEngine.ts
# │   │   ├── Task.ts
# │   │   ├── Tool.ts
# │   │   ├── commands.ts
# │   │   ├── context.ts
# │   │   ├── cost-tracker.ts
# │   │   ├── costHook.ts
# │   │   ├── dialogLaunchers.tsx
# │   │   ├── history.ts
# │   │   ├── ink.ts
# │   │   ├── interactiveHelpers.tsx
# │   │   ├── main.tsx
# │   │   ├── projectOnboardingState.ts
# │   │   ├── query.ts
# │   │   ├── replLauncher.tsx
# │   │   ├── setup.ts
# │   │   ├── tasks.ts
# │   │   ├── tools.ts
# │   │   └── workspace_exploration.ipynb
# │   ├── continue/
# │   │   ├── actions/
# │   │   ├── binary/
# │   │   ├── core/
# │   │   ├── docs/
# │   │   ├── eval/
# │   │   ├── extensions/
# │   │   ├── gui/
# │   │   ├── manual-testing-sandbox/
# │   │   ├── media/
# │   │   ├── packages/
# │   │   ├── scripts/
# │   │   ├── sync/
# │   │   ├── CLA.md
# │   │   ├── CODE_OF_CONDUCT.md
# │   │   ├── CONTRIBUTING.md
# │   │   ├── LICENSE
# │   │   ├── README.md
# │   │   ├── REPO_ORGANIZATION.md
# │   │   ├── SECURITY.md
# │   │   ├── package-lock.json
# │   │   ├── package.json
# │   │   ├── tsconfig.json
# │   │   └── worktree-config.yaml
# │   ├── cool-notebooks/
# │   │   ├── notebooks/
# │   │   ├── notebooks_v1/
# │   │   ├── notebooks_v2/
# │   │   ├── tools/
# │   │   ├── website/
# │   │   ├── LICENSE-CODE
# │   │   ├── LICENSE-TEXT
# │   │   ├── README.md
# │   │   ├── environment.yml
# │   │   └── requirements.txt
# │   ├── ezpass/
# │   │   ├── statements/
# │   │   ├── ezpass_analysis.ipynb
# │   │   └── utils.py
# │   ├── finviz/
# │   │   ├── finviz/
# │   │   ├── LICENSE
# │   │   ├── README.rst
# │   │   ├── example.py
# │   │   ├── poetry.lock
# │   │   ├── pyproject.toml
# │   │   ├── requirements.txt
# │   │   ├── setup.cfg
# │   │   └── setup.py
# │   ├── investpy/
# │   │   ├── docs/
# │   │   ├── investpy/
# │   │   ├── investpy.egg-info/
# │   │   ├── requirements/
# │   │   ├── tests/
# │   │   ├── LICENSE
# │   │   ├── MANIFEST.in
# │   │   ├── README.md
# │   │   ├── setup.cfg
# │   │   └── setup.py
# │   ├── jupyterlab/
# │   │   ├── binder/
# │   │   ├── builder/
# │   │   ├── buildutils/
# │   │   ├── design/
# │   │   ├── dev_mode/
# │   │   ├── docker/
# │   │   ├── docs/
# │   │   ├── examples/
# │   │   ├── galata/
# │   │   ├── jupyter-config/
# │   │   ├── jupyterlab/
# │   │   ├── packages/
# │   │   ├── scripts/
# │   │   ├── testutils/
# │   │   ├── AGENTS.md
# │   │   ├── CHANGELOG.md
# │   │   ├── CLAUDE.md
# │   │   ├── CONTRIBUTING.md
# │   │   ├── CORPORATE.md
# │   │   ├── LICENSE
# │   │   ├── README.md
# │   │   ├── RELEASE.md
# │   │   ├── buildapi.py
# │   │   ├── clean.py
# │   │   ├── conftest.py
# │   │   ├── jupyterlab.desktop
# │   │   ├── jupyterlab.svg
# │   │   ├── lerna.json
# │   │   ├── package.json
# │   │   ├── postcss.config.js
# │   │   ├── pyproject.toml
# │   │   ├── setup.py
# │   │   ├── tsconfig.eslint.json
# │   │   ├── tsconfigbase.json
# │   │   ├── tsconfigbase.test.json
# │   │   ├── typedoc.base.json
# │   │   ├── typedoc.js
# │   │   └── yarn.lock
# │   ├── notebook/
# │   │   ├── app/
# │   │   ├── binder/
# │   │   ├── buildutils/
# │   │   ├── docs/
# │   │   ├── jupyter-config/
# │   │   ├── notebook/
# │   │   ├── packages/
# │   │   ├── tests/
# │   │   ├── ui-tests/
# │   │   ├── CHANGELOG.md
# │   │   ├── CONTRIBUTING.md
# │   │   ├── LICENSE
# │   │   ├── README.md
# │   │   ├── RELEASE.md
# │   │   ├── eslint.config.mjs
# │   │   ├── jupyter-notebook.desktop
# │   │   ├── jupyter.svg
# │   │   ├── jupyter_config.json
# │   │   ├── lerna.json
# │   │   ├── notebook.svg
# │   │   ├── nx.json
# │   │   ├── package.json
# │   │   ├── pixi.lock
# │   │   ├── pyproject.toml
# │   │   ├── setup.py
# │   │   ├── tsconfig.eslint.json
# │   │   ├── tsconfigbase.json
# │   │   ├── tsconfigbase.test.json
# │   │   └── yarn.lock
# │   ├── opencode/
# │   │   ├── github/
# │   │   ├── infra/
# │   │   ├── nix/
# │   │   ├── packages/
# │   │   ├── patches/
# │   │   ├── script/
# │   │   ├── sdks/
# │   │   ├── specs/
# │   │   ├── AGENTS.md
# │   │   ├── ARCHITECTURE.md
# │   │   ├── CONTRIBUTING.md
# │   │   ├── LICENSE
# │   │   ├── README.ar.md
# │   │   ├── README.bn.md
# │   │   ├── README.br.md
# │   │   ├── README.bs.md
# │   │   ├── README.da.md
# │   │   ├── README.de.md
# │   │   ├── README.es.md
# │   │   ├── README.fr.md
# │   │   ├── README.gr.md
# │   │   ├── README.it.md
# │   │   ├── README.ja.md
# │   │   ├── README.ko.md
# │   │   ├── README.md
# │   │   ├── README.no.md
# │   │   ├── README.pl.md
# │   │   ├── README.ru.md
# │   │   ├── README.th.md
# │   │   ├── README.tr.md
# │   │   ├── README.uk.md
# │   │   ├── README.vi.md
# │   │   ├── README.zh.md
# │   │   ├── README.zht.md
# │   │   ├── SECURITY.md
# │   │   ├── STATS.md
# │   │   ├── bun.lock
# │   │   ├── bunfig.toml
# │   │   ├── flake.lock
# │   │   ├── flake.nix
# │   │   ├── install
# │   │   ├── package.json
# │   │   ├── sst-env.d.ts
# │   │   ├── sst.config.ts
# │   │   ├── tsconfig.json
# │   │   └── turbo.json
# │   ├── pi-mono/
# │   │   ├── packages/
# │   │   ├── scripts/
# │   │   ├── AGENTS.md
# │   │   ├── CONTRIBUTING.md
# │   │   ├── LICENSE
# │   │   ├── README.md
# │   │   ├── ai-sdk-repos.code-workspace
# │   │   ├── biome.json
# │   │   ├── package-lock.json
# │   │   ├── package.json
# │   │   ├── pi-mono.code-workspace
# │   │   ├── pi-test.sh
# │   │   ├── test.sh
# │   │   ├── tsconfig.base.json
# │   │   └── tsconfig.json
# │   ├── poly-maker/
# │   │   ├── data/
# │   │   ├── data_updater/
# │   │   ├── log/
# │   │   ├── poly_data/
# │   │   ├── poly_merger/
# │   │   ├── poly_stats/
# │   │   ├── poly_utils/
# │   │   ├── positions/
# │   │   ├── scripts/
# │   │   ├── INSTRUCTIONS.md
# │   │   ├── LOGGING.md
# │   │   ├── README.md
# │   │   ├── credentials.json
# │   │   ├── main.py
# │   │   ├── pyproject.toml
# │   │   ├── test_logger.py
# │   │   ├── trading.py
# │   │   ├── update_markets.py
# │   │   ├── update_stats.py
# │   │   └── uv.lock
# │   ├── quant-mono/
# │   │   ├── Classes/
# │   │   ├── DataServices/
# │   │   ├── K15Credentials/
# │   │   ├── K15CythonExtensions/
# │   │   ├── K15Lab/
# │   │   ├── K15PandasCalendars/
# │   │   ├── Modules/
# │   │   ├── Scripts/
# │   │   ├── Signal/
# │   │   ├── Sys/
# │   │   ├── UDF/
# │   │   ├── backtest/
# │   │   ├── bbg_api/
# │   │   ├── bo/
# │   │   ├── connector/
# │   │   ├── dashboard/
# │   │   ├── dask-worker-space/
# │   │   ├── db/
# │   │   ├── docs/
# │   │   ├── finmath/
# │   │   ├── log/
# │   │   ├── procedures/
# │   │   ├── reports/
# │   │   ├── scheduler/
# │   │   ├── strategy/
# │   │   ├── tests/
# │   │   ├── utils/
# │   │   ├── _____teste.py
# │   │   ├── _____teste2.py
# │   │   ├── bfg-1.14.0.jar
# │   │   ├── blp.txt
# │   │   ├── desktop.ini
# │   │   ├── index
# │   │   └── requirements.txt
# │   ├── research/
# │   │   ├── Balerion/
# │   │   ├── ChatGPT/
# │   │   ├── Crypto/
# │   │   ├── Dourado/
# │   │   ├── Dracarys/
# │   │   ├── FactSet/
# │   │   ├── GS Quant/
# │   │   ├── Google Trends/
# │   │   ├── Index Rebal/
# │   │   ├── Opening Gap/
# │   │   ├── Pairs Trading/
# │   │   ├── RQA/
# │   │   ├── Seasonality/
# │   │   ├── Sell Side Revisions/
# │   │   ├── TCA/
# │   │   ├── Viserion/
# │   │   ├── X/
# │   │   ├── exegy/
# │   │   ├── investpy/
# │   │   ├── sqzme/
# │   │   ├── yfinance/
# │   │   ├── Compare Intraday to Daily Resampled Data.ipynb
# │   │   ├── Test Intraday Routine.ipynb
# │   │   ├── gold_monday_performance.ipynb
# │   │   └── run_jns_loop.py
# │   ├── typedecorator/
# │   │   ├── typedecorator/
# │   │   ├── typedecorator.egg-info/
# │   │   ├── README.md
# │   │   ├── setup.py
# │   │   ├── tests.py
# │   │   └── tests3.py
# │   ├── unity/
# │   │   ├── docs/
# │   │   ├── src/
# │   │   ├── test/
# │   │   ├── CONTRIBUTING.md
# │   │   ├── LICENSE
# │   │   ├── README.md
# │   │   ├── SECURITY.md
# │   │   ├── package-lock.json
# │   │   ├── package.json
# │   │   ├── tsconfig.json
# │   │   ├── tsup.config.ts
# │   │   └── vitest.config.ts
# │   ├── warp/
# │   │   ├── app/
# │   │   ├── command-signatures-v2/
# │   │   ├── crates/
# │   │   ├── docker/
# │   │   ├── resources/
# │   │   ├── script/
# │   │   ├── specs/
# │   │   ├── CODE_OF_CONDUCT.md
# │   │   ├── CONTRIBUTING.md
# │   │   ├── Cargo.lock
# │   │   ├── Cargo.toml
# │   │   ├── LICENSE-AGPL
# │   │   ├── LICENSE-MIT
# │   │   ├── PSScriptAnalyzerCustomRules.psm1
# │   │   ├── README.md
# │   │   ├── SECURITY.md
# │   │   ├── WARP.md
# │   │   ├── about.hbs
# │   │   ├── about.toml
# │   │   ├── deny.toml
# │   │   ├── diesel.toml
# │   │   ├── fake
# │   │   └── rust-toolchain.toml
# │   ├── yahoo-earnings-calendar/
# │   │   ├── tests/
# │   │   ├── yahoo_earnings_calendar/
# │   │   ├── yahoo_earnings_calendar.egg-info/
# │   │   ├── LICENSE
# │   │   ├── Makefile
# │   │   ├── Pipfile
# │   │   ├── Pipfile.lock
# │   │   ├── README.md
# │   │   ├── codecov.yml
# │   │   ├── requirements.txt
# │   │   ├── setup.cfg
# │   │   └── setup.py
# │   ├── Orion-mono.code-workspace
# │   ├── docx_reader.ipynb
# │   ├── orion_loc_counter.ipynb
# │   ├── we-are-all-back-at-the-command-line-shorter.md
# │   ├── we-are-all-back-at-the-command-line.md
# │   └── x_article_publish_helper.ipynb
# ├── Google Drive/
# │   ├── My Drive/
# │   │   ├── $/
# │   │   ├── Colab Notebooks/
# │   │   ├── Gemini Gems/
# │   │   ├── Google AI Studio/
# │   │   ├── IFL/
# │   │   ├── Insper/
# │   │   ├── Intercâmbio/
# │   │   ├── K&F LTDA/
# │   │   ├── Literatura/
# │   │   ├── Masters/
# │   │   ├── Pessoal/
# │   │   ├── Poker/
# │   │   ├── Saved from Chrome/
# │   │   ├── Trabalho/
# │   │   ├── Transfer/
# │   │   ├── Travel & Tickets/
# │   │   ├── BCE_Reflection_Paper_Nicolas.docx
# │   │   ├── Copy of PhotoRobot_Financing_Presentation.pptx
# │   │   ├── PhotoRobot Financials.gsheet
# │   │   ├── Pigeon Deployment: A Deep State Conspiracy.gdoc
# │   │   ├── PolyMM.gsheet
# │   │   ├── Simulating Customer Behavior with AI.gdoc
# │   │   ├── Trade Allocation Problem v1.docx
# │   │   ├── Trade Allocation Problem v1.gdoc
# │   │   ├── Untitled document.gdoc
# │   │   ├── Untitled spreadsheet.gsheet
# │   │   ├── add the context window and max output token to th....gsheet
# │   │   ├── meake a 2 page cheat sheet covering the material....gdoc
# │   │   └── transcsv.gsheet
# │   └── Other computers/
# │       ├── My Laptop/
# │       └── USB and External Devices/
# ├── Library/
# │   ├── Accessibility/
# │   │   ├── com.apple.RTTTranscripts_ckAssets/
# │   │   ├── com.apple.personalaudio_ckAssets/
# │   │   ├── com.apple.RTTTranscripts.sqlite
# │   │   ├── com.apple.RTTTranscripts.sqlite-shm
# │   │   ├── com.apple.RTTTranscripts.sqlite-wal
# │   │   ├── com.apple.personalaudio.sqlite
# │   │   ├── com.apple.personalaudio.sqlite-shm
# │   │   └── com.apple.personalaudio.sqlite-wal
# │   ├── Accounts/
# │   ├── AppleMediaServices/
# │   ├── Application Scripts/
# │   │   ├── 049B2EBF-475F-4BF2-B9F6-B8878BE10783/
# │   │   ├── 1C39BA7F-CE17-47A8-ADE6-D4FB8B433F3B/
# │   │   ├── 23B463B1-42CE-447A-BEED-BC8A017D3D6F/
# │   │   ├── 243LU875E5.groups.com.apple.podcasts/
# │   │   ├── 2DC432GLL2.com.openai.sky.CUAService/
# │   │   ├── 316C6D57-9EB3-4F76-989F-8CC92B27599B/
# │   │   ├── 3TH5R7YS88.group.com.anchorfree.hss-mac/
# │   │   ├── 4ADD4797-CC05-432F-96E2-1C43DB1AEF97/
# │   │   ├── 7A789025-8E67-49B5-B547-500BF1DD6EEE/
# │   │   ├── 852817CA-087F-442C-97AA-A54FF40A4DB4/
# │   │   ├── B64DA702-5029-4AF5-BC10-529265789DDE/
# │   │   ├── BJ4HAAB9B3.ZoomClient3rd/
# │   │   ├── D3B34985-867C-4BE9-9918-1878B8ACCB74/
# │   │   ├── E8B2152B-BC1C-4268-9979-299000E951A1/
# │   │   ├── E8D10C07-A66F-4D36-84A5-42FAA77DC662/
# │   │   ├── ED144ADA-145A-4CCB-BB24-79893FE15F94/
# │   │   ├── EQHXZ8M8AV.group.com.google.drivefs/
# │   │   ├── FB73916D-C3FA-4F17-B774-7C22C160251B/
# │   │   ├── RP2S87B72W.eu.exelban.Stats.widgets/
# │   │   ├── SY64MV22J9.com.raycast.macos.shared/
# │   │   ├── UBF8T346G9.Office/
# │   │   ├── UBF8T346G9.OfficeExcelWidget/
# │   │   ├── UBF8T346G9.OfficeOneDriveSyncIntegration/
# │   │   ├── UBF8T346G9.OfficeOsfWebHost/
# │   │   ├── UBF8T346G9.OfficePPTWidget/
# │   │   ├── UBF8T346G9.OfficeWordWidget/
# │   │   ├── UBF8T346G9.OneDriveStandaloneSuite/
# │   │   ├── UBF8T346G9.com.microsoft.entrabroker/
# │   │   ├── UBF8T346G9.com.microsoft.oneauth/
# │   │   ├── UBF8T346G9.com.microsoft.rdc/
# │   │   ├── UBF8T346G9.com.microsoft.teams/
# │   │   ├── UBF8T346G9.group.com.microsoft.shared/
# │   │   ├── UBF8T346G9.ms/
# │   │   ├── com.anchorfree.hss-mac/
# │   │   ├── com.anchorfree.hss-mac.HydraTunnelProvider/
# │   │   ├── com.anchorfree.hss-mac.WireGuardTunnelProvider/
# │   │   ├── com.anchorfree.hss-mac.hydra/
# │   │   ├── com.anchorfree.hss-mac.startatloginhelper/
# │   │   ├── com.anchorfree.hss-mac.wireguard/
# │   │   ├── com.apple.AMPArtworkAgent/
# │   │   ├── com.apple.AMPDeviceDiscoveryAgent/
# │   │   ├── com.apple.AMSUIPaymentViewService/
# │   │   ├── com.apple.AVConference.Diagnostic/
# │   │   ├── com.apple.Accessibility-Settings.extension/
# │   │   ├── com.apple.AccessibilitySettingsWidgetExtension/
# │   │   ├── com.apple.AccountsUISettings.AppIntents/
# │   │   ├── com.apple.ActionKit.BundledIntentHandler/
# │   │   ├── com.apple.AddressBook/
# │   │   ├── com.apple.AirDrop-Handoff-Settings.extension/
# │   │   ├── com.apple.AirPlayUIAgent/
# │   │   ├── com.apple.Animoji.StickersApp.MessagesExtension/
# │   │   ├── com.apple.AppSSOKerberos.KerberosExtension/
# │   │   ├── com.apple.AppStore/
# │   │   ├── com.apple.AppStoreDaemon.ASDAskPermissionExtension/
# │   │   ├── com.apple.Appearance-Settings.extension/
# │   │   ├── com.apple.AppleAccountIntents/
# │   │   ├── com.apple.AppleAccountUI.AAUIFollowUpExtension/
# │   │   ├── com.apple.AppleMediaServices.FollowUpExtension/
# │   │   ├── com.apple.AppleMediaServicesUI.ComposeReviewExtension/
# │   │   ├── com.apple.AppleMediaServicesUI.UtilityExtension/
# │   │   ├── com.apple.AquaAppearanceHelper/
# │   │   ├── com.apple.Arabesque/
# │   │   ├── com.apple.AskToMessagesHost.AskToExtension/
# │   │   ├── com.apple.AskToMessagesHost.AskToMessagesExtension/
# │   │   ├── com.apple.AuthKit.AKDiagnosticExtension/
# │   │   ├── com.apple.AuthKitUI.AKAppSSOExtension/
# │   │   ├── com.apple.AuthKitUI.AKFollowUpServerUIExtension/
# │   │   ├── com.apple.AutoFillPanelService/
# │   │   ├── com.apple.AvatarUI.AvatarPickerMemojiEditor/
# │   │   ├── com.apple.AvatarUI.AvatarPickerMemojiPicker/
# │   │   ├── com.apple.AvatarUI.AvatarPickerPosePicker/
# │   │   ├── com.apple.BKAgentService/
# │   │   ├── com.apple.Batteries/
# │   │   ├── com.apple.Batteries.BatteriesAvocadoWidgetExtension/
# │   │   ├── com.apple.Battery-Settings.extension/
# │   │   ├── com.apple.BiometricsAndPasswordSettingsAppIntentsExtension/
# │   │   ├── com.apple.BlackPowderInferenceExtension/
# │   │   ├── com.apple.BluetoothSettings/
# │   │   ├── com.apple.BluetoothSettingsApp.BluetoothSettingsAppIntentsWidget/
# │   │   ├── com.apple.CD-DVD-Settings.extension/
# │   │   ├── com.apple.CMViewSrvc/
# │   │   ├── com.apple.CTLazuliSupport.diagnosticextension/
# │   │   ├── com.apple.CalendarFileHandler/
# │   │   ├── com.apple.CalendarUI.SpotlightEventPreview/
# │   │   ├── com.apple.CalendarWeatherKitService/
# │   │   ├── com.apple.CalendarWidget.IntentsExtension/
# │   │   ├── com.apple.CaptiveNetworkAssistant/
# │   │   ├── com.apple.ClassKit-Settings.extension/
# │   │   ├── com.apple.ClassKit.ClassKitAppIntents/
# │   │   ├── com.apple.ClassKit.diagnosticextension/
# │   │   ├── com.apple.Classroom-Settings.extension/
# │   │   ├── com.apple.ClassroomDeviceExpert/
# │   │   ├── com.apple.CloudDocs.iCloudDriveFileProvider/
# │   │   ├── com.apple.CloudDocs.iCloudDriveFileProviderManaged/
# │   │   ├── com.apple.CloudDocsDaemon.StorageManagement/
# │   │   ├── com.apple.CloudDocsDaemon.diagnostic/
# │   │   ├── com.apple.CloudKit.ShareBear/
# │   │   ├── com.apple.CloudPhotosConfiguration/
# │   │   ├── com.apple.CloudSharingUI.CopyLink/
# │   │   ├── com.apple.CloudSharingUI.invite/
# │   │   ├── com.apple.CloudSubscriptionFeatures.CSFFollowUpExtension/
# │   │   ├── com.apple.CommerceKit.AskPermissionExtension/
# │   │   ├── com.apple.ConfigurationProfiles.FollowUp/
# │   │   ├── com.apple.ContactsUI.ContactViewViewService/
# │   │   ├── com.apple.ContactsUI.ContactsViewService/
# │   │   ├── com.apple.ContinuityCaptureOnboardingUI/
# │   │   ├── com.apple.ControlCenter-Settings.extension/
# │   │   ├── com.apple.CoreCDPUI.CDPFollowUpExtension/
# │   │   ├── com.apple.CoreDevice.remotepairingd/
# │   │   ├── com.apple.CoreHapticsTools.QLPreviewExtension/
# │   │   ├── com.apple.CoreHapticsTools.QLThumbnailExtension/
# │   │   ├── com.apple.CoreRoutine.RTDiagnosticExtension/
# │   │   ├── com.apple.CoreRoutine.helperservice/
# │   │   ├── com.apple.Coverage-Settings.extension/
# │   │   ├── com.apple.CryptoTokenKit.ctkcard.ctkcardtoken/
# │   │   ├── com.apple.CryptoTokenKit.pivtoken/
# │   │   ├── com.apple.DEC.AppPredictionInternal.DiagnosticExtension/
# │   │   ├── com.apple.DataDetectorsLocalSources/
# │   │   ├── com.apple.DataDetectorsViewService/
# │   │   ├── com.apple.Date-Time-Settings.extension/
# │   │   ├── com.apple.DeskCam/
# │   │   ├── com.apple.Desktop-Settings.extension/
# │   │   ├── com.apple.DeviceActivityUI.DeviceActivityReportService/
# │   │   ├── com.apple.DiagnosticExtensions.AirPlay/
# │   │   ├── com.apple.DiagnosticExtensions.AppleBtcDiagnosis/
# │   │   ├── com.apple.DiagnosticExtensions.BluetoothDiagnosticExtension/
# │   │   ├── com.apple.DiagnosticExtensions.BluetoothHeadset/
# │   │   ├── com.apple.DiagnosticExtensions.HomeEnergyDiagnosticExtension/
# │   │   ├── com.apple.DiagnosticExtensions.IntelligentRoutingDiagnostic/
# │   │   ├── com.apple.DiagnosticExtensions.MiLoDiagnostic/
# │   │   ├── com.apple.DiagnosticExtensions.PICSDiagnosticExtension/
# │   │   ├── com.apple.DiagnosticExtensions.WiFi/
# │   │   ├── com.apple.DiagnosticExtensions.shortcuts/
# │   │   ├── com.apple.DiagnosticExtensions.sysdiagnose/
# │   │   ├── com.apple.Dictionary/
# │   │   ├── com.apple.DifferentialPrivacy.TelemetryAggregator/
# │   │   ├── com.apple.DiskSpaceDiagnostics.diagnosticextension/
# │   │   ├── com.apple.Displays-Settings.extension/
# │   │   ├── com.apple.DoNotDisturb.Intents/
# │   │   ├── com.apple.ExtensionsSettings.DefaultExtensionEnablement/
# │   │   ├── com.apple.ExtensionsSettings.LegacyPluginEnablementExtension/
# │   │   ├── com.apple.FaceTime/
# │   │   ├── com.apple.FaceTime.FaceTimeNotificationExtension/
# │   │   ├── com.apple.FaceTime.RemotePeoplePicker/
# │   │   ├── com.apple.Family/
# │   │   ├── com.apple.Family-Settings.extension/
# │   │   ├── com.apple.FamilyControlsAgent/
# │   │   ├── com.apple.Feedback.DraftingExtension/
# │   │   ├── com.apple.FileProviderDaemon.diagnostic/
# │   │   ├── com.apple.Flurry/
# │   │   ├── com.apple.Focus-Settings.extension/
# │   │   ├── com.apple.FollowUpSettings.FollowUpSettingsExtension/
# │   │   ├── com.apple.FontBook/
# │   │   ├── com.apple.Game-Center-Settings.extension/
# │   │   ├── com.apple.Game-Controller-Settings.extension/
# │   │   ├── com.apple.GameCenter.Settings.DeviceExpertExtension/
# │   │   ├── com.apple.GameCenterDiagnosticExtension/
# │   │   ├── com.apple.GenerativePlaygroundApp.remoteUIExtension/
# │   │   ├── com.apple.HeadGestures.diagnosticextension.HeadGesturesDiagnosticExtension/
# │   │   ├── com.apple.HeadphoneSettings/
# │   │   ├── com.apple.Home/
# │   │   ├── com.apple.Home.HomeEnergyWidgets/
# │   │   ├── com.apple.Home.HomeUIUserList/
# │   │   ├── com.apple.Home.HomeWidget.Interactive/
# │   │   ├── com.apple.Home.group/
# │   │   ├── com.apple.HomeAppIntentsExtension/
# │   │   ├── com.apple.HomeKitEvents.HomeKitEventsDiagnosticExtension/
# │   │   ├── com.apple.HydraQLPreviewExtension/
# │   │   ├── com.apple.HydraQLThumbnailExtension/
# │   │   ├── com.apple.HydraUSDAppIntents/
# │   │   ├── com.apple.IOUIAgent/
# │   │   ├── com.apple.ImageIO.imageimporter/
# │   │   ├── com.apple.ImagePlayground.DiagnosticExtension/
# │   │   ├── com.apple.ImagePlayground.NonUIExtension/
# │   │   ├── com.apple.InferenceProviderService/
# │   │   ├── com.apple.Internet-Accounts-Settings.extension/
# │   │   ├── com.apple.Keyboard-Settings.extension/
# │   │   ├── com.apple.LighthouseBitacoraFramework.BitacoraWorker/
# │   │   ├── com.apple.LighthouseBitacoraFramework.LighthouseBitacoraPlugin/
# │   │   ├── com.apple.LinkPresentation.LinkSnapshotGeneratorService/
# │   │   ├── com.apple.LinkedNotesUIService/
# │   │   ├── com.apple.Localization-Settings.extension/
# │   │   ├── com.apple.Lock-Screen-Settings.extension/
# │   │   ├── com.apple.LoginItems-Settings.extension/
# │   │   ├── com.apple.LookupViewService/
# │   │   ├── com.apple.MailCacheDelete/
# │   │   ├── com.apple.MailShareExtension/
# │   │   ├── com.apple.ManagedSettings.ManagedSettingsMacOSExtension/
# │   │   ├── com.apple.Maps/
# │   │   ├── com.apple.MarkupUI.Markup/
# │   │   ├── com.apple.MarkupUI.MarkupPhotoExtension/
# │   │   ├── com.apple.MediaExtensions-Settings/
# │   │   ├── com.apple.MediaMLPluginApp.MediaMLExtension/
# │   │   ├── com.apple.MediaMLPluginApp.MediaMLPlugin/
# │   │   ├── com.apple.MediaPlayer.DiagnosticExtension/
# │   │   ├── com.apple.MobileSMS/
# │   │   ├── com.apple.MobileSMS.MessagesActionExtension/
# │   │   ├── com.apple.MobileSMS.MessagesPluginNotificationExtension/
# │   │   ├── com.apple.Mouse-Settings.extension/
# │   │   ├── com.apple.Music.MusicCacheExtension/
# │   │   ├── com.apple.Music.MusicStorageExtension/
# │   │   ├── com.apple.Network-Settings.extension/
# │   │   ├── com.apple.NetworkExtension.IKEv2Provider/
# │   │   ├── com.apple.NetworkExtensionSettingsUI.NESettingsUIExtension/
# │   │   ├── com.apple.NetworkInfo.DiagnosticExtension/
# │   │   ├── com.apple.NewDeviceOutreach.NewDeviceOutreachIntents/
# │   │   ├── com.apple.NewDeviceOutreachMac.Extension/
# │   │   ├── com.apple.Notes/
# │   │   ├── com.apple.Notes.IntentsExtension/
# │   │   ├── com.apple.Notes.QuickLookExtension/
# │   │   ├── com.apple.Notes.SharingExtension/
# │   │   ├── com.apple.Notes.SpotlightIndexExtension/
# │   │   ├── com.apple.Notes.WidgetExtension/
# │   │   ├── com.apple.Notifications-Settings.extension/
# │   │   ├── com.apple.OFDPreview/
# │   │   ├── com.apple.OFDThumbnail/
# │   │   ├── com.apple.OSDUIHelper/
# │   │   ├── com.apple.PDFKit.PDFExtensionView/
# │   │   ├── com.apple.PDFKit.PDFImporter/
# │   │   ├── com.apple.PaperKit.extension.ui/
# │   │   ├── com.apple.Pass-Viewer/
# │   │   ├── com.apple.PassKit.PaymentAuthorizationUIExtension/
# │   │   ├── com.apple.PassKitUIXPCService/
# │   │   ├── com.apple.PassbookUIService.PeerPaymentMessagesExtension/
# │   │   ├── com.apple.Passwords-Settings.extension/
# │   │   ├── com.apple.PeopleMessageService.AskToBuy/
# │   │   ├── com.apple.PeopleMessageService.LegacyMessageService/
# │   │   ├── com.apple.PeopleMessageService.ScreenTime/
# │   │   ├── com.apple.PeopleViewService/
# │   │   ├── com.apple.PeopleViewService.PeopleWidget-macOS/
# │   │   ├── com.apple.PeopleViewService.SelectPerson-iOS/
# │   │   ├── com.apple.PhotoBooth/
# │   │   ├── com.apple.PhotoLibraryServices.PhotosDiagnostics/
# │   │   ├── com.apple.Photos/
# │   │   ├── com.apple.Photos.MacMusicPickerExtension/
# │   │   ├── com.apple.Photos.PhotosFileProvider/
# │   │   ├── com.apple.Photos.PhotosReliveWidget/
# │   │   ├── com.apple.Photos.StorageManagementExtension/
# │   │   ├── com.apple.PhotosIntelligence.PhotosStoryDiagnostics/
# │   │   ├── com.apple.PlatformSSOToken/
# │   │   ├── com.apple.PressAndHold/
# │   │   ├── com.apple.Preview/
# │   │   ├── com.apple.PreviewLegacySignaturesConversion/
# │   │   ├── com.apple.Print-Scan-Settings.extension/
# │   │   ├── com.apple.Profiles-Settings.extension/
# │   │   ├── com.apple.Profiles-Settings.intents/
# │   │   ├── com.apple.QuickLookUIFramework.QLPreviewGenerationExtension/
# │   │   ├── com.apple.QuickTimePlayerX/
# │   │   ├── com.apple.RAQLPreviewExtension/
# │   │   ├── com.apple.RAQLThumbnailExtension/
# │   │   ├── com.apple.RelativeMotion.TempestDiagnosticExtension/
# │   │   ├── com.apple.STMExtension.AppleInternal/
# │   │   ├── com.apple.STMExtension.Applications/
# │   │   ├── com.apple.STMExtension.Developer/
# │   │   ├── com.apple.STMExtension.GarageBand/
# │   │   ├── com.apple.STMExtension.Mail/
# │   │   ├── com.apple.STMExtension.OtherUsers/
# │   │   ├── com.apple.STMExtension.Trash/
# │   │   ├── com.apple.STMExtension.iOSFiles/
# │   │   ├── com.apple.Safari/
# │   │   ├── com.apple.Safari.BrowserDataImportingService/
# │   │   ├── com.apple.Safari.CacheDeleteExtension/
# │   │   ├── com.apple.Safari.DiagnosticExtension/
# │   │   ├── com.apple.Safari.SafariLinkExtension/
# │   │   ├── com.apple.Safari.SafariQuickLookPreview/
# │   │   ├── com.apple.Safari.SafariWidgetExtension/
# │   │   ├── com.apple.Safari.WebApp/
# │   │   ├── com.apple.SafariFoundation.CredentialProviderExtensionHelper/
# │   │   ├── com.apple.SafariPlatformSupport.Helper/
# │   │   ├── com.apple.SceneKitQLPreviewExtension/
# │   │   ├── com.apple.SceneKitQLThumbnailExtension/
# │   │   ├── com.apple.Screen-Time-Settings.extension/
# │   │   ├── com.apple.ScreenContinuity/
# │   │   ├── com.apple.ScreenSaver-Settings.extension/
# │   │   ├── com.apple.ScreenSaver.Computer-Name/
# │   │   ├── com.apple.ScreenSaver.Drift/
# │   │   ├── com.apple.ScreenSaver.Engine.legacyScreenSaver/
# │   │   ├── com.apple.ScreenSaver.Engine.legacyScreenSaver.x86-64/
# │   │   ├── com.apple.ScreenSaver.Hello/
# │   │   ├── com.apple.ScreenSaver.Monterey/
# │   │   ├── com.apple.ScreenSaver.Ventura/
# │   │   ├── com.apple.ScreenSaver.iLife-Slideshow-Extension/
# │   │   ├── com.apple.ScreenTime.ScreenTimeWebExtension/
# │   │   ├── com.apple.ScreenTimeAgent/
# │   │   ├── com.apple.ScreenTimeSwift.ScreenTimeDeviceActivityMonitorExtension/
# │   │   ├── com.apple.ScreenTimeWidgetApplication.ScreenTimeWidgetExtension/
# │   │   ├── com.apple.ScreenTimeWidgetApplication.ScreenTimeWidgetIntentsExtension/
# │   │   ├── com.apple.Sharing-Settings.extension/
# │   │   ├── com.apple.Shell/
# │   │   ├── com.apple.Siri-Settings.extension/
# │   │   ├── com.apple.SiriMetrics.SiriTurnRestatementExtension/
# │   │   ├── com.apple.SiriUI.SiriUISetupXPC/
# │   │   ├── com.apple.SmartReplies.SmartRepliesMLRuntimePlugin/
# │   │   ├── com.apple.Software-Update-Settings.extension/
# │   │   ├── com.apple.SoftwareUpdate.SoftwareUpdateSettingsWidget/
# │   │   ├── com.apple.SonicKit.diagnostics/
# │   │   ├── com.apple.Sound-Settings.SoundIntents/
# │   │   ├── com.apple.Sound-Settings.extension/
# │   │   ├── com.apple.Spotlight-Settings.extension/
# │   │   ├── com.apple.Spotlight-Settings.extension.SpotlightSettingsIntentsExtension/
# │   │   ├── com.apple.Startup-Disk-Settings.extension/
# │   │   ├── com.apple.StartupDisk.StartupDiskWidgetExtension/
# │   │   ├── com.apple.Stickers.UserGenerated.MessagesExtension/
# │   │   ├── com.apple.StoreKit.SKAskPermissionExtension/
# │   │   ├── com.apple.SystemExtensions-Settings.extension/
# │   │   ├── com.apple.SystemProfiler.AboutExtension/
# │   │   ├── com.apple.TV.TVCacheExtension/
# │   │   ├── com.apple.TV.TVStorageExtension/
# │   │   ├── com.apple.TelephonyUtilities.PhoneIntentHandler/
# │   │   ├── com.apple.TextEdit/
# │   │   ├── com.apple.TextToSpeechVoiceBankingSupport.VoiceBankingDiagnostics/
# │   │   ├── com.apple.Time-Machine-Settings-Intents.extension/
# │   │   ├── com.apple.Time-Machine-Settings.extension/
# │   │   ├── com.apple.Touch-ID-Settings.extension/
# │   │   ├── com.apple.Trackpad-Settings.extension/
# │   │   ├── com.apple.Transfer-Reset-Settings.extension/
# │   │   ├── com.apple.Translation.TranslationAPISupportExtension/
# │   │   ├── com.apple.TranslationUIServices.TranslationUIService/
# │   │   ├── com.apple.TransparencySettingsIntents/
# │   │   ├── com.apple.TransparencyUI.FollowUpExtension/
# │   │   ├── com.apple.TransparencyUI.SWTFollowUpExtension/
# │   │   ├── com.apple.UIUnderstanding.diagnosticextension/
# │   │   ├── com.apple.UniversalAccess.UASettingsShortcuts/
# │   │   ├── com.apple.UsageTrackingAgent/
# │   │   ├── com.apple.Users-Groups-Settings.extension/
# │   │   ├── com.apple.VPNAppIntentWidget/
# │   │   ├── com.apple.VideoSubscriberAccount.VideoSubscriberAccountUIFramework.AuthenticationExtension/
# │   │   ├── com.apple.VisualGeneration.inference/
# │   │   ├── com.apple.VoiceMemos/
# │   │   ├── com.apple.VoiceMemos.SpotlightIndexExtension/
# │   │   ├── com.apple.VoiceMemos.VoiceMemosIntentsExtension/
# │   │   ├── com.apple.VoiceMemos.VoiceMemosSettingsWidget/
# │   │   ├── com.apple.WalletSettingsExtension/
# │   │   ├── com.apple.Wallpaper-Settings.extension/
# │   │   ├── com.apple.WatchFaceAlert.ThumbnailExtension/
# │   │   ├── com.apple.WiFiVelocity.DiagnosticExtension/
# │   │   ├── com.apple.WordOfTheDay/
# │   │   ├── com.apple.WorkflowKit.ShortcutsIntents/
# │   │   ├── com.apple.WorkflowUI.AddShortcutExtension/
# │   │   ├── com.apple.WorkflowUI.CatalystContentExtension/
# │   │   ├── com.apple.WorkflowUI.WidgetConfigurationExtension/
# │   │   ├── com.apple.aiml.RepackagingWorker/
# │   │   ├── com.apple.aiml.mlpt.FedStats.MLHostPlugin/
# │   │   ├── com.apple.aiml.mlpt.FedStats.MLHostPluginClassA/
# │   │   ├── com.apple.aiml.mlpt.FedStats.MLHostPluginClassB/
# │   │   ├── com.apple.aiml.mlpt.PriML.FedStats.Plugin/
# │   │   ├── com.apple.aiml.mlpt.PriML.FedStats.PluginClassB/
# │   │   ├── com.apple.aiml.mlpt.PriML.FedStats.PluginNonDnU/
# │   │   ├── com.apple.ap.PromotedContentPrediction.APOdmlSearchResultsExtension/
# │   │   ├── com.apple.appkit.xpc.ColorSampler/
# │   │   ├── com.apple.archiveutility/
# │   │   ├── com.apple.ax.KonaTTSSupport.KonaSynthesizer/
# │   │   ├── com.apple.ax.MauiTTSSupport.MauiAUSP/
# │   │   ├── com.apple.batteryui.BatterySettingsIntents/
# │   │   ├── com.apple.bird/
# │   │   ├── com.apple.calculator.CalculatorWidget/
# │   │   ├── com.apple.calendar.CalendarIntentsExtension/
# │   │   ├── com.apple.calendar.EventKitUIRemoteUIExtension/
# │   │   ├── com.apple.clock/
# │   │   ├── com.apple.clock.WorldClockWidget/
# │   │   ├── com.apple.cloudml.inference.PrivateMLClientInferenceProviderService/
# │   │   ├── com.apple.contacts.donation-agent/
# │   │   ├── com.apple.controlcenter.ControlCenterSettingsIntents/
# │   │   ├── com.apple.corerecents.recentsd/
# │   │   ├── com.apple.das.DASDaemon.DuetDiagnosticExtension/
# │   │   ├── com.apple.desktopsettings.DesktopSettingsIntents/
# │   │   ├── com.apple.diagnosticextensions.osx.filevault/
# │   │   ├── com.apple.diagnosticextensions.osx.installlog/
# │   │   ├── com.apple.diagnosticextensions.osx.spotlight/
# │   │   ├── com.apple.diagnosticextensions.osx.syslog/
# │   │   ├── com.apple.diagnosticextensions.osx.systemprofile/
# │   │   ├── com.apple.diagnosticextensions.osx.timemachine/
# │   │   ├── com.apple.donotdisturb.DoNotDisturbAppIntents/
# │   │   ├── com.apple.dp.PrivateFederatedLearning.DPMLRuntimePlugin/
# │   │   ├── com.apple.dp.PrivateFederatedLearning.DPMLRuntimePluginClassB/
# │   │   ├── com.apple.dp.PrivateFederatedLearning.DPMLRuntimePluginNonDnU/
# │   │   ├── com.apple.eventMetaDataExtractor.eventMetaDataExtractorPlugin/
# │   │   ├── com.apple.eventkit.CalendarDiagnosticExtension/
# │   │   ├── com.apple.extensionkit.AppExtensionManagement/
# │   │   ├── com.apple.facetime.NotificationViewBridgeService/
# │   │   ├── com.apple.family.FAFollowupExtension/
# │   │   ├── com.apple.family.FamilyIntents/
# │   │   ├── com.apple.findmy/
# │   │   ├── com.apple.findmy.FindMyIntents/
# │   │   ├── com.apple.findmy.FindMyNotificationsServiceExtension/
# │   │   ├── com.apple.findmy.FindMyWidgetItems/
# │   │   ├── com.apple.findmy.FindMyWidgetPeople/
# │   │   ├── com.apple.freeform/
# │   │   ├── com.apple.freeform.USDRendererExtension/
# │   │   ├── com.apple.freeform.sharingextension/
# ...
# │   │   ├── com.apple.PersonalAudio.plist
# │   │   ├── com.apple.PhotoBooth.plist
# │   │   ├── com.apple.ProblemReporter.plist
# │   │   ├── com.apple.ReportCrash.plist
# │   │   ├── com.apple.Safari.PasswordBreachAgent.plist
# │   │   ├── com.apple.Safari.SafeBrowsing.plist
# │   │   ├── com.apple.Safari.plist
# │   │   ├── com.apple.SafariBookmarksSyncAgent.plist
# │   │   ├── com.apple.SafariCloudHistoryPushAgent.plist
# │   │   ├── com.apple.ScreenContinuity.plist
# │   │   ├── com.apple.ServicesMenu.Services.plist
# │   │   ├── com.apple.SetupAssistant.plist
# │   │   ├── com.apple.Siri.plist
# │   │   ├── com.apple.SiriExperimentMetricsWorker.plist
# │   │   ├── com.apple.SiriMetricsWorker.plist
# │   │   ├── com.apple.SocialLayer.plist
# │   │   ├── com.apple.SoftwareUpdate.plist
# │   │   ├── com.apple.SpeakSelection.plist
# │   │   ├── com.apple.SpeechRecognitionCore.plist
# │   │   ├── com.apple.Spotlight.plist
# │   │   ├── com.apple.SpotlightResources.Defaults.plist
# │   │   ├── com.apple.StatusKitAgent.plist
# │   │   ├── com.apple.StocksKitService.plist
# │   │   ├── com.apple.StoreKit.plist
# │   │   ├── com.apple.SystemProfiler.plist
# │   │   ├── com.apple.TTY.plist
# │   │   ├── com.apple.TV.plist
# │   │   ├── com.apple.TelephonyUtilities.plist
# │   │   ├── com.apple.TelephonyUtilities.sharePlayAppPolicies.plist
# │   │   ├── com.apple.Terminal.plist
# │   │   ├── com.apple.Terminal.plist.bak
# │   │   ├── com.apple.TextInputMenu.plist
# │   │   ├── com.apple.TextInputMenuAgent.plist
# │   │   ├── com.apple.TrustedPeersHelper.plist
# │   │   ├── com.apple.UnifiedAssetFramework.plist
# │   │   ├── com.apple.UserAccountUpdater.plist
# │   │   ├── com.apple.Wallet.plist
# │   │   ├── com.apple.Wallpaper-Settings.extension.plist
# │   │   ├── com.apple.WatchListKit.plist
# │   │   ├── com.apple.WindowManager.plist
# │   │   ├── com.apple.accessibility.heard.plist
# │   │   ├── com.apple.accessory.Hearing.plist
# │   │   ├── com.apple.accounts.suggestions.plist
# │   │   ├── com.apple.accountsd.plist
# │   │   ├── com.apple.amp.mediasharingd.plist
# │   │   ├── com.apple.amsengagementd.plist
# │   │   ├── com.apple.animoji.plist
# │   │   ├── com.apple.ap.adprivacyd.plist
# │   │   ├── com.apple.appkit.xpc.openAndSavePanelService.plist
# │   │   ├── com.apple.appleaccount.informationcache.plist
# │   │   ├── com.apple.appleaccount.plist
# │   │   ├── com.apple.appleaccountd.plist
# │   │   ├── com.apple.appplaceholdersyncd.plist
# │   │   ├── com.apple.appstorecomponentsd.plist
# │   │   ├── com.apple.appstored.plist
# │   │   ├── com.apple.assistant.backedup.plist
# │   │   ├── com.apple.assistant.plist
# │   │   ├── com.apple.assistant.support.plist
# │   │   ├── com.apple.assistantd.plist
# │   │   ├── com.apple.biomesyncd.plist
# │   │   ├── com.apple.bird.plist
# │   │   ├── com.apple.bluetoothuserd.plist
# │   │   ├── com.apple.bookstoreagent.plist
# │   │   ├── com.apple.businessservicesd.plist
# │   │   ├── com.apple.calaccessd.plist
# │   │   ├── com.apple.chronod.plist
# │   │   ├── com.apple.classroom.plist
# │   │   ├── com.apple.cloud.quota.plist
# │   │   ├── com.apple.cloudd.plist
# │   │   ├── com.apple.cloudpaird.plist
# │   │   ├── com.apple.cloudphotod.plist
# │   │   ├── com.apple.cmfsyncagent.plist
# │   │   ├── com.apple.commcenter.callservices.plist
# │   │   ├── com.apple.commcenter.data.plist
# │   │   ├── com.apple.commcenter.plist
# │   │   ├── com.apple.commerce.configurator.plist
# │   │   ├── com.apple.commerce.knownclients.plist
# │   │   ├── com.apple.commerce.plist
# │   │   ├── com.apple.contextsync.subscriptions.plist
# │   │   ├── com.apple.controlcenter.helper.plist
# │   │   ├── com.apple.controlcenter.plist
# │   │   ├── com.apple.coreservices.UASharedPasteboardProgressUI.plist
# │   │   ├── com.apple.coreservices.uiagent.plist
# │   │   ├── com.apple.coreservices.useractivityd.dynamicuseractivites.plist
# │   │   ├── com.apple.coreservices.useractivityd.plist
# │   │   ├── com.apple.corespotlightui.plist
# │   │   ├── com.apple.cseventlistener.plist
# │   │   ├── com.apple.dataaccess.babysitter.plist
# │   │   ├── com.apple.dataaccess.dataaccessd.plist
# │   │   ├── com.apple.diagnosticextensionsd.plist
# │   │   ├── com.apple.dock.plist
# │   │   ├── com.apple.donotdisturbd.plist
# │   │   ├── com.apple.driver.AppleBluetoothMultitouch.mouse.plist
# │   │   ├── com.apple.driver.AppleBluetoothMultitouch.trackpad.plist
# │   │   ├── com.apple.driver.AppleHIDMouse.plist
# │   │   ├── com.apple.facetime.bag.plist
# │   │   ├── com.apple.fileproviderd.plist
# │   │   ├── com.apple.financed.plist
# │   │   ├── com.apple.finder.plist
# │   │   ├── com.apple.findmy.findmylocateagent.plist
# │   │   ├── com.apple.gamecenter.plist
# │   │   ├── com.apple.gamed.plist
# │   │   ├── com.apple.gms.availability.plist
# │   │   ├── com.apple.helpd.plist
# │   │   ├── com.apple.homed.notbackedup.plist
# │   │   ├── com.apple.homed.plist
# │   │   ├── com.apple.homeenergyd.plist
# │   │   ├── com.apple.iApps.plist
# │   │   ├── com.apple.iCal.plist
# │   │   ├── com.apple.iChat.plist
# │   │   ├── com.apple.iCloudNotificationAgent.plist
# │   │   ├── com.apple.iTunes.plist
# │   │   ├── com.apple.icloud.searchpartyuseragent.plist
# │   │   ├── com.apple.iclouddrive.features.plist
# │   │   ├── com.apple.identityservicesd.plist
# │   │   ├── com.apple.ids.deviceproperties.plist
# │   │   ├── com.apple.ids.plist
# │   │   ├── com.apple.ids.subservices.plist
# │   │   ├── com.apple.imagecapture.plist
# │   │   ├── com.apple.imagent.plist
# │   │   ├── com.apple.imdpersistence.IMDPersistenceAgent.plist
# │   │   ├── com.apple.imdsmsrecordstore.plist
# │   │   ├── com.apple.imessage.bag.plist
# │   │   ├── com.apple.imessage.plist
# │   │   ├── com.apple.imservice.ids.FaceTime.plist
# │   │   ├── com.apple.imservice.ids.iMessage.plist
# │   │   ├── com.apple.inputAnalytics.IASGenmojiAnalyzer.plist
# │   │   ├── com.apple.inputAnalytics.IASGenmojiUsageAnalyzer.plist
# │   │   ├── com.apple.inputAnalytics.IASSRAnalyzer.plist
# │   │   ├── com.apple.inputAnalytics.IASWTAnalyzer.plist
# │   │   ├── com.apple.inputAnalytics.serverStats.plist
# │   │   ├── com.apple.internal.ck.plist
# │   │   ├── com.apple.ipTelephony.plist
# │   │   ├── com.apple.itunescloud.daemon.plist
# │   │   ├── com.apple.itunescloud.plist
# │   │   ├── com.apple.itunescloudd.plist
# │   │   ├── com.apple.itunesstored.plist
# │   │   ├── com.apple.keyboardservicesd.plist
# │   │   ├── com.apple.knowledge-agent.plist
# │   │   ├── com.apple.locationaccessstored.plist
# │   │   ├── com.apple.loginwindow.plist
# │   │   ├── com.apple.madrid.plist
# │   │   ├── com.apple.mediaanalysisd.plist
# │   │   ├── com.apple.mediaplaybackcore.plist
# │   │   ├── com.apple.menuextra.clock.plist
# │   │   ├── com.apple.messages.commsafety.plist
# │   │   ├── com.apple.messages.critical-messaging.storage.plist
# │   │   ├── com.apple.messages.nicknames.plist
# │   │   ├── com.apple.messages.pinning.plist
# │   │   ├── com.apple.messaging.expire.plist
# │   │   ├── com.apple.metrickitd.plist
# │   │   ├── com.apple.mlhost.plist
# │   │   ├── com.apple.mmcs.plist
# │   │   ├── com.apple.mobileipod.plist
# │   │   ├── com.apple.mobiletimer.plist
# │   │   ├── com.apple.mobiletimerd.plist
# │   │   ├── com.apple.ncprefs.plist
# │   │   ├── com.apple.network.eapclient.tls.TrustExceptions.plist
# │   │   ├── com.apple.networkserviceproxy.plist
# │   │   ├── com.apple.newscore.plist
# │   │   ├── com.apple.newscore2.plist
# │   │   ├── com.apple.newsd.plist
# │   │   ├── com.apple.onetimepasscodes.plist
# │   │   ├── com.apple.parsecd.plist
# │   │   ├── com.apple.passd.class-d.plist
# │   │   ├── com.apple.passd.plist
# │   │   ├── com.apple.people.plist
# │   │   ├── com.apple.photos.shareddefaults.plist
# │   │   ├── com.apple.preferences.extensions.ShareMenu.plist
# │   │   ├── com.apple.print.custompresets.forprinter.EPSON_L8180_Series.plist
# │   │   ├── com.apple.print.custompresets.forprinter.HornLibSecure.plist
# │   │   ├── com.apple.print.custompresets.forprinter.OlinSecure.plist
# │   │   ├── com.apple.print.custompresets.plist
# │   │   ├── com.apple.printcenter.plist
# │   │   ├── com.apple.privatecloudcomputed.plist
# │   │   ├── com.apple.proactive.PersonalizationPortrait.plist
# │   │   ├── com.apple.protectedcloudstorage.protectedcloudkeysyncing.plist
# │   │   ├── com.apple.quicklook.ThumbnailsAgent.plist
# │   │   ├── com.apple.rapport.plist
# │   │   ├── com.apple.registration.plist
# │   │   ├── com.apple.remindd.babysitter.plist
# │   │   ├── com.apple.remindd.plist
# │   │   ├── com.apple.replayd.plist
# │   │   ├── com.apple.scheduler.plist
# │   │   ├── com.apple.screencapture.plist
# │   │   ├── com.apple.screencaptureui.plist
# │   │   ├── com.apple.screensaver.plist
# │   │   ├── com.apple.scriptmenu.plist
# │   │   ├── com.apple.security.cloudkeychainproxy3.keysToRegister.plist
# │   │   ├── com.apple.security.ctkd-db.plist
# │   │   ├── com.apple.security.sosaccount.plist
# │   │   ├── com.apple.seeding.plist
# │   │   ├── com.apple.seserviced.plist
# │   │   ├── com.apple.settings.PrivacySecurity.extension.plist
# │   │   ├── com.apple.sharingd.plist
# │   │   ├── com.apple.siri.ODDI.MetricsWorker.plist
# │   │   ├── com.apple.siri.ODDI.PoirotMetricsWorker.plist
# │   │   ├── com.apple.siri.VoiceShortcuts.plist
# │   │   ├── com.apple.siri.analytics.assistant.plist
# │   │   ├── com.apple.siri.context.service.plist
# │   │   ├── com.apple.siri.morphun.plist
# │   │   ├── com.apple.siri.shortcuts.plist
# │   │   ├── com.apple.siri.sirisuggestions.plist
# │   │   ├── com.apple.siriactionsd.plist
# │   │   ├── com.apple.siriknowledged.plist
# │   │   ├── com.apple.sms.plist
# │   │   ├── com.apple.sociallayerd.CloudKit.ckwriter.plist
# │   │   ├── com.apple.sociallayerd.plist
# │   │   ├── com.apple.spaces.plist
# │   │   ├── com.apple.speech.recognition.AppleSpeechRecognition.prefs.plist
# │   │   ├── com.apple.spotlight.mdwrite.plist
# │   │   ├── com.apple.spotlightknowledge.plist
# │   │   ├── com.apple.stickersd.plist
# │   │   ├── com.apple.stockholm.plist
# │   │   ├── com.apple.stocks.stockskit.plist
# │   │   ├── com.apple.storeagent.plist
# │   │   ├── com.apple.studentd.plist
# │   │   ├── com.apple.suggestd.plist
# │   │   ├── com.apple.suggestions.plist
# │   │   ├── com.apple.symbolichotkeys.plist
# │   │   ├── com.apple.syncdefaultsd.plist
# │   │   ├── com.apple.systempreferences.plist
# │   │   ├── com.apple.systemuiserver.plist
# │   │   ├── com.apple.talagent.plist
# │   │   ├── com.apple.textInput.keyboardServices.textReplacement.plist
# │   │   ├── com.apple.tipsd.plist
# │   │   ├── com.apple.translationd.plist
# │   │   ├── com.apple.transparencyd.plist
# │   │   ├── com.apple.triald.plist
# │   │   ├── com.apple.universalaccess.plist
# │   │   ├── com.apple.universalaccessAuthWarning.plist
# │   │   ├── com.apple.usernotificationsd.plist
# │   │   ├── com.apple.voiceservices.plist
# │   │   ├── com.apple.voicetrigger.notbackedup.plist
# │   │   ├── com.apple.voicetrigger.plist
# │   │   ├── com.apple.wallpaper.plist
# │   │   ├── com.apple.weather.sensitive.plist
# │   │   ├── com.apple.widgets.plist
# │   │   ├── com.apple.wifi.WiFiAgent.plist
# │   │   ├── com.apple.xpc.activity2.plist
# │   │   ├── com.cisco.webex.Cisco-WebEx-Start.plist
# │   │   ├── com.clipy-app.Clipy.plist
# │   │   ├── com.crowdcafe.windowmagnet.plist
# │   │   ├── com.electron.wispr-flow.plist
# │   │   ├── com.google.Chrome.plist
# │   │   ├── com.google.Keystone.Agent.plist
# │   │   ├── com.google.drivefs.helper.renderer.plist
# │   │   ├── com.google.drivefs.plist
# │   │   ├── com.google.drivefs.settings.plist
# │   │   ├── com.hnc.Discord.helper.Renderer.plist
# │   │   ├── com.hnc.Discord.plist
# │   │   ├── com.microsoft.OneDriveStandaloneUpdater.plist
# │   │   ├── com.microsoft.OneDriveUpdater.plist
# │   │   ├── com.microsoft.SharePoint-mac.plist
# │   │   ├── com.microsoft.autoupdate.fba.plist
# │   │   ├── com.microsoft.autoupdate2.plist
# │   │   ├── com.microsoft.office.plist
# │   │   ├── com.microsoft.shared.plist
# │   │   ├── com.openai.codex.plist
# │   │   ├── com.openai.sky.CUAService.cli.plist
# │   │   ├── com.openai.sky.CUAService.plist
# │   │   ├── com.pharos.popup.plist
# │   │   ├── com.raycast.macos.plist
# │   │   ├── com.readdle.SparkDesktop.helper.plist
# │   │   ├── com.readdle.SparkDesktop.plist
# │   │   ├── com.rstudio.desktop.plist
# │   │   ├── com.spotify.client.plist
# │   │   ├── com.timpler.screenstudio.plist
# │   │   ├── com.tinyspeck.slackmacgap.plist
# │   │   ├── com.todesktop.230313mzl4w4u92.plist
# │   │   ├── diagnostics_agent.plist
# │   │   ├── eu.exelban.Stats.plist
# │   │   ├── familycircled.plist
# │   │   ├── group.com.apple.mail.plist
# │   │   ├── icloudmailagent.plist
# │   │   ├── internetAccountsMigrator.plist
# │   │   ├── loginwindow.plist
# │   │   ├── mbuseragent.plist
# │   │   ├── net.freemacsoft.AppCleaner.plist
# │   │   ├── notion.id.plist
# │   │   ├── org.R-project.R.plist
# │   │   ├── org.cups.PrintingPrefs.plist
# │   │   ├── pbs.plist
# │   │   ├── sharedfilelistd.plist
# │   │   ├── systemgroup.com.apple.icloud.searchpartyd.sharedsettings.plist
# │   │   ├── us.zoom.ZoomAutoUpdater.plist
# │   │   ├── us.zoom.updater.config.plist
# │   │   ├── us.zoom.updater.plist
# │   │   └── us.zoom.xos.plist
# │   ├── Printers/
# │   ├── PrivateCloudCompute/
# │   ├── Python/
# │   │   └── 3.9/
# │   ├── ResponseKit/
# │   │   ├── de-dynamic.lm/
# │   │   ├── en-dynamic.lm/
# │   │   ├── hu-dynamic.lm/
# │   │   └── pt-dynamic.lm/
# │   ├── Safari/
# │   ├── SafariSafeBrowsing/
# │   │   └── SafeBrowsingRemoteConfiguration-1.plist
# │   ├── Screen Savers/
# │   ├── Services/
# │   ├── Sharing/
# │   ├── Shortcuts/
# │   ├── Sounds/
# │   │   ├── codex-notification.wav
# │   │   └── notification.wav
# │   ├── Spelling/
# │   │   ├── LocalDictionary
# │   │   └── dynamic-counts.dat
# │   ├── Spotlight/
# │   │   └── ExtensionsCache/
# │   ├── StatusKit/
# │   ├── Suggestions/
# │   ├── Translation/
# │   │   └── Hotfix/
# │   ├── Trial/
# │   ├── UnifiedAssetFramework/
# │   │   └── history/
# │   ├── Weather/
# │   ├── WebKit/
# │   │   ├── Cisco-Systems.Spark/
# │   │   ├── Databases/
# │   │   ├── com.apple.WalletSettingsExtension/
# │   │   ├── com.raycast.macos/
# │   │   ├── com.spotify.client/
# │   │   ├── com.stremio.stremio-shell-macos/
# │   │   ├── eu.exelban.Stats/
# │   │   └── us.zoom.xos/
# │   ├── com.apple.AppleMediaServices/
# │   │   └── PersistedBags/
# │   ├── com.apple.aiml.instrumentation/
# │   ├── com.apple.appleaccountd/
# │   │   ├── CKTokens/
# │   │   ├── CustodianHealthRecord/
# │   │   ├── CustodianRecord/
# │   │   ├── CustodianRecoveryInfoRecord/
# │   │   └── CustodianshipInfoRecord/
# │   ├── com.apple.bluetooth.services.cloud/
# │   │   ├── CKTokens/
# │   │   └── CachedRecords/
# │   ├── com.apple.bluetoothuser/
# │   │   └── Production/
# │   ├── com.apple.iTunesCloud/
# │   │   ├── ICMusicUserProfileResponsesCache/
# │   │   ├── play_activity.sqlitedb
# │   │   ├── play_activity.sqlitedb-shm
# │   │   └── play_activity.sqlitedb-wal
# │   ├── com.apple.icloud.searchpartyd/
# │   │   ├── BeaconEstimatedLocation/
# │   │   ├── BeaconNamingRecord/
# │   │   ├── BeaconObservationStore/
# │   │   ├── BeaconProductInfoRecord/
# │   │   ├── CKTokens/
# │   │   ├── KeyAlignmentRecords/
# │   │   ├── LeashRecords/
# │   │   ├── LostModeRecords/
# │   │   ├── OwnedBeaconGroups/
# │   │   ├── OwnedBeacons/
# │   │   ├── OwnedDeviceKeyRecord/
# │   │   ├── SafeLocations/
# │   │   ├── CloudStorage.db-shm
# │   │   ├── CloudStorage.db-wal
# │   │   ├── CloudStorage_CKRecordCache.db-shm
# │   │   └── CloudStorage_CKRecordCache.db-wal
# │   ├── com.apple.internal.ck/
# │   ├── homeenergyd/
# │   │   └── com.apple.homeenergyd/
# │   ├── pnpm/
# │   │   └── store/
# │   ├── studentd/
# │   └── Application
# ├── Movies/
# │   └── TV/
# ├── Music/
# │   └── Music/
# ├── Pictures/
# │   ├── Photo Booth Library/
# │   └── Photos Library.photoslibrary/
# ├── Public/
# │   └── Drop Box/
# ├── Screen Studio Projects/
# │   └── Unity#1.screenstudio/
# │       ├── recording/
# │       ├── meta.json
# │       ├── project.json
# │       └── recording-markers.json
# ├── go/
# │   └── pkg/
# │       ├── mod/
# │       └── sumdb/
# └── mba/
#     └── oim.ipynb
#
# === WORKSPACE STATS ===
# {
#   "total_files": 573608,
#   "total_size_mb": 107002.93,
#   "top_extensions": {
#     "no_extension": 446231,
#     ".ts": 9901,
#     ".thumb": 9227,
#     ".js": 8758,
#     ".json": 7625,
#     ".r": 7159,
#     ".ipynb": 5630,
#     ".h": 5415,
#     ".svg": 5116,
#     ".log": 4974
#   }
# }
