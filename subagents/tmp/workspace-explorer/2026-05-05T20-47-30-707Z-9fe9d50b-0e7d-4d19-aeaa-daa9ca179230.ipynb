# %% [markdown]
# # Workspace Explorer

# %% [markdown]
# ## Description
# Explores the local workspace filesystem, analyzes project structure, searches for files or text, and summarizes the workspace layout. Use when you need to understand the project directory structure, locate specific files or configurations, find where variables/functions are defined, or get a general lay of the land in an unfamiliar repository.

# %% [markdown]
# ## System Prompt
# You are an autonomous workspace explorer sub-agent. Your goal is to rapidly and accurately comprehend the structure, contents, and purpose of the local project directory.
#
# **Expected Input:**
# The parent agent will provide a description of what to look for (e.g., 'summarize the project structure', 'find where the database connection is established', or 'list all markdown files').
#
# **Capabilities & Best Practices:**
# 1. **Python Utilities First:** Use the `WorkspaceExplorer` Python class provided in the scratchpad cells below. It is designed to safely summarize large directories, respect common ignore patterns (like `node_modules` or `.git`), and avoid context-window overflows.
# 2. **Avoid Massive Outputs:** Never run unrestricted `find .` or `tree` commands, and avoid printing entire large files. Always use depth limits (`max_depth`) and read snippets.
# 3. **Fallback to Bash:** Use the `bash` tool (with `rg`, `fd`, `find`) if you need complex command-line searches not covered by the Python utilities.
# 4. **Read Files:** Use the `read_file` tool to inspect the exact contents of files once you locate them.
# 5. **Read-Only:** You are strictly read-only. Do not modify, move, or delete files.
#
# **Final Output:**
# Return a concise, structured markdown summary to the parent agent. Include the most relevant file paths, a high-level project architecture, and direct answers to the parent's specific queries.

# %%
import os
print('This is your current working directoy:', os.getcwd())
# Out:
# This is your current working directoy: /Users/nicolasfonteyne/.agents/subagents/tmp/workspace-explorer

# %%
# Reusable Workspace Explorer Python Utility
import re
from pathlib import Path
from collections import Counter
import json

class WorkspaceExplorer:
    def __init__(self, root="."):
        self.root = Path(root).resolve()
        # Common directories and files to ignore to keep context clean
        self.ignore_dirs = {'.git', 'node_modules', 'venv', '.venv', 'env', '__pycache__', '.pytest_cache', 'build', 'dist', '.next', 'coverage', '.idea', '.vscode'}
        self.ignore_exts = {'.pyc', '.pdf', '.png', '.jpg', '.jpeg', '.gif', '.zip', '.tar', '.gz', '.mp4', '.sqlite3', '.db', '.DS_Store'}

    def _is_ignored(self, path: Path) -> bool:
        if path.name in self.ignore_dirs:
            return True
        if path.suffix.lower() in self.ignore_exts:
            return True
        return False

    def get_tree(self, max_depth=2) -> str:
        """Generates a clean tree view of the directory up to max_depth."""
        tree_str = []
        
        def walk(current_path, prefix="", depth=0):
            if depth > max_depth:
                return
            try:
                entries = sorted(list(current_path.iterdir()), key=lambda x: (not x.is_dir(), x.name))
            except PermissionError:
                return
                
            entries = [e for e in entries if not self._is_ignored(e) and not e.name.startswith('.')]
            
            for i, entry in enumerate(entries):
                is_last = (i == len(entries) - 1)
                connector = "└── " if is_last else "├── "
                tree_str.append(f"{prefix}{connector}{entry.name}{'/' if entry.is_dir() else ''}")
                
                if entry.is_dir():
                    extension = "    " if is_last else "│   "
                    walk(entry, prefix + extension, depth + 1)
                    
        tree_str.append(f"📂 {self.root.name}/")
        walk(self.root)
        return "\n".join(tree_str)

    def get_stats(self) -> dict:
        """Returns a dictionary of file counts by extension and total size."""
        ext_counts = Counter()
        total_size = 0
        file_count = 0
        
        for dirpath, dirnames, filenames in os.walk(self.root):
            # Modify dirnames in-place to skip ignored directories
            dirnames[:] = [d for d in dirnames if d not in self.ignore_dirs and not d.startswith('.')]
            
            for f in filenames:
                p = Path(dirpath) / f
                if self._is_ignored(p) or f.startswith('.'):
                    continue
                ext = p.suffix.lower() or 'no_extension'
                ext_counts[ext] += 1
                file_count += 1
                try:
                    total_size += p.stat().st_size
                except OSError:
                    pass
                    
        return {
            "total_files": file_count,
            "total_size_mb": round(total_size / (1024 * 1024), 2),
            "top_extensions": dict(ext_counts.most_common(10))
        }
        
    def find_content(self, pattern: str, max_results=15) -> list:
        """Searches for a regex pattern in files, returning a list of matched lines."""
        matches = []
        try:
            regex = re.compile(pattern, re.IGNORECASE)
        except re.error:
            return ["Invalid regex pattern"]
            
        for dirpath, dirnames, filenames in os.walk(self.root):
            dirnames[:] = [d for d in dirnames if d not in self.ignore_dirs and not d.startswith('.')]
            
            for f in filenames:
                if len(matches) >= max_results:
                    return matches
                    
                p = Path(dirpath) / f
                if self._is_ignored(p) or f.startswith('.'):
                    continue
                    
                try:
                    with open(p, 'r', encoding='utf-8', errors='ignore') as file:
                        for line_no, line in enumerate(file, 1):
                            if regex.search(line):
                                matches.append(f"{p.relative_to(self.root)}:{line_no}: {line.strip()[:120]}")
                                if len(matches) >= max_results:
                                    break
                except Exception:
                    pass
        return matches

# %%
# Run this cell to instantly get a high-level overview of the project structure and stats
explorer = WorkspaceExplorer()

print("=== WORKSPACE TREE (Depth=2) ===")
print(explorer.get_tree(max_depth=2))

print("\n=== WORKSPACE STATS ===")
print(json.dumps(explorer.get_stats(), indent=2))

# print("\n=== EXAMPLE SEARCH ===")
# for match in explorer.find_content(r"database_url", max_results=5):
#     print(match)
# Out:
# === WORKSPACE TREE (Depth=2) ===
# 📂 quant-mono/
# ├── Classes/
# │   ├── Asset.py
# │   ├── BBG.py
# │   ├── CheckingProcedures.py
# │   ├── FixedIncome.py
# │   ├── K15Tools.py
# │   ├── Log.py
# │   ├── Metadata.py
# │   ├── Pricing.py
# │   ├── Reports.py
# │   ├── Risk.py
# │   ├── RiskMetrics.py
# │   ├── SSHUtil.py
# │   ├── Scenarios.py
# │   ├── Signal.py
# │   ├── Synthetics.py
# │   ├── WLInputs.py
# │   └── desktop.ini
# ├── DataServices/
# │   ├── BCB/
# │   │   ├── __init__.py
# │   │   ├── copom_meeting_dates.py
# │   │   └── copom_statements.py
# │   ├── Binance/
# │   │   ├── resources/
# │   │   ├── scripts/
# │   │   ├── MarketData.py
# │   │   └── __init__.py
# │   ├── Bloomberg/
# │   │   └── Bloomberg.py
# │   ├── Exegy/
# │   │   ├── __init__.py
# │   │   └── exegy.py
# │   ├── FRED/
# │   │   ├── resources/
# │   │   ├── FRED.py
# │   │   └── __init__.py
# │   ├── Goldman/
# │   │   ├── __init__.py
# │   │   ├── main.py
# │   │   └── script_goldman_data.py
# │   ├── Procedures/
# │   │   ├── DataRequisition/
# │   │   └── __init__.py
# │   ├── Reuters/
# │   │   ├── docs/
# │   │   ├── Reuters.py
# │   │   └── __init__.py
# │   ├── Sqzme/
# │   │   ├── __init__.py
# │   │   ├── create_ubs_nasdaq_data.py
# │   │   └── main.py
# │   ├── UBS/
# │   │   ├── __init__.py
# │   │   ├── crowding_factor.py
# │   │   ├── index_rebalance_api.py
# │   │   ├── populate_ubs_crowding_factor_data.py
# │   │   ├── ubs_index_rebalance_post.py
# │   │   └── ubs_index_rebalance_predictions.py
# │   ├── benzinga/
# │   │   ├── __init__.py
# │   │   └── benzinga.py
# │   ├── factset/
# │   │   ├── examples/
# │   │   ├── __init__.py
# │   │   ├── formula_api.py
# │   │   └── sdk.py
# │   ├── refinitiv/
# │   │   ├── __init__.py
# │   │   ├── refinitiv.py
# │   │   └── rqa.py
# │   ├── web_scrappers/
# │   │   ├── fin_screener.py
# │   │   └── zacks.py
# │   ├── __init__.py
# │   └── generic.py
# ├── K15Credentials/
# │   ├── resources/
# │   │   ├── keys.xml
# │   │   └── keys_tmp.xml
# │   ├── __init__.py
# │   ├── keys.py
# │   └── setup.py
# ├── K15CythonExtensions/
# │   ├── Teste/
# │   │   └── teste.pyx
# │   └── setup.py
# ├── K15Lab/
# │   ├── Backtester/
# │   │   ├── reports/
# │   │   ├── resources/
# │   │   ├── __init__.py
# │   │   ├── backtester.py
# │   │   └── timeseries_backtester.py
# │   ├── Common/
# │   │   ├── __init__.py
# │   │   ├── auxiliar_methods.py
# │   │   ├── element_checking.py
# │   │   ├── noconflict.py
# │   │   ├── outer_bridge.py
# │   │   └── wrappers.py
# │   ├── Dataset/
# │   │   ├── resources/
# │   │   ├── __init__.py
# │   │   ├── cross_sectional_dataset.py
# │   │   ├── panel_dataset.py
# │   │   └── timeseries_dataset.py
# │   ├── Indicators/
# │   │   ├── Risk/
# │   │   ├── Rolling/
# │   │   └── __init__.py
# │   ├── Model/
# │   │   ├── resources/
# │   │   ├── __init__.py
# │   │   ├── cross_sectional_model.py
# │   │   ├── model.py
# │   │   ├── panel_model.py
# │   │   └── timeseries_model.py
# │   ├── OMS/
# │   │   ├── Order/
# │   │   └── __init__.py
# │   ├── OrderRouter/
# │   │   └── MongoDB/
# │   ├── Signal/
# │   │   ├── resources/
# │   │   ├── __init__.py
# │   │   ├── cross_sectional_signal.py
# │   │   ├── panel_signal.py
# │   │   ├── signal.py
# │   │   └── timeseries_signal.py
# │   ├── Strategy/
# │   │   ├── resources/
# │   │   ├── __init__.py
# │   │   ├── panel_strategy.py
# │   │   └── timeseries_strategy.py
# │   └── __init__.py
# ├── K15PandasCalendars/
# │   ├── OtherCalendars/
# │   │   ├── exchange_anbima_calendar.py
# │   │   ├── exchange_calendar_bmf_complete.py
# │   │   ├── exchange_comex_metals.py
# │   │   └── exchange_nymex_energy.py
# │   ├── Source/
# │   │   └── calendar_registry.py
# │   └── __init__.py
# ├── Modules/
# │   ├── TechnicalAnalysisAndPlots.py
# │   ├── aux_functions.py
# │   ├── bo_calculations.py
# │   ├── csv2wealthlab.py
# │   ├── desktop.ini
# │   ├── intraday_rolled_series_2_wealthlab.py
# │   ├── metadata_adjustments.py
# │   ├── mongo_functions.py
# │   ├── multiprocessing_functions.py
# │   ├── numpyctypes.py
# │   ├── other.py
# │   ├── postgresql_functions.py
# │   ├── reuters_daily_download.py
# │   ├── ssh_remote_routines.py
# │   ├── tickhistory.py
# │   └── xlwings_utilities.py
# ├── Scripts/
# │   ├── metadata_/
# │   │   ├── remove_bbg_routine_new_metadata.py
# │   │   └── script_populate_trading_costs_new_metadata.py
# │   ├── delete_all_intraday_and_EOD.py
# │   ├── dev_gen_verify_quality_prices.py
# │   ├── dev_script_update_eod_csv_db.py
# │   ├── gen_carry_file.py
# │   ├── gen_signals.py
# │   ├── gen_synthetics_eod.py
# │   ├── gen_trend_file.py
# │   ├── gen_txt_file.py
# │   ├── gen_verify_quality_prices.py
# │   ├── gerencial_backup.py
# │   ├── match_notional.py
# │   ├── metadata_chunk_import.py
# │   ├── rename_strategies_in_db.py
# │   ├── routine_import_datascope_daily_file.py
# │   ├── script_bbg_eod.py
# │   ├── script_create_cash_equity_margin_cost.py
# │   ├── script_intraday_2_daily.py
# │   ├── script_intraday_rolled_series_2_wealthlab.py
# │   ├── script_match_bofa_margin.py
# │   ├── script_populate_metadata.py
# │   ├── script_register_nongenerics.py
# │   ├── script_reuters_get_data.py
# │   ├── script_safety_reuters_download.py
# │   ├── script_update_eod_csv_db.py
# │   ├── script_update_lme_rolling_futures.py
# │   ├── script_update_registry.py
# │   └── tetete.tex
# ├── Signal/
# │   ├── Carry/
# │   │   ├── Equity/
# │   │   └── Carry.py
# │   ├── predictive_model/
# │   │   ├── examples/
# │   │   ├── __init__.py
# │   │   ├── _generic.py
# │   │   ├── aggregation_models.py
# │   │   ├── back_test_predictive_models.py
# │   │   ├── linear_models.py
# │   │   └── non_linear_models.py
# │   ├── seasonality/
# │   │   ├── examples.py
# │   │   └── seasonality.py
# │   ├── __init__.py
# │   └── _generic.py
# ├── Sys/
# │   ├── SysAllocator.py
# │   ├── SysBT.py
# │   ├── SysDataset.py
# │   ├── SysModel.py
# │   ├── SysMultivariateAnalysisAndModeling.py
# │   ├── SysOptimizer.py
# │   ├── SysRiskContributionMethods.py
# │   ├── SysSignal.py
# │   ├── SysStats.py
# │   ├── SysUnivariateAnalysisAndModeling.py
# │   └── __init__.py
# ├── UDF/
# │   ├── cache-directory/
# │   │   └── 2029240f6d1128be89ddc32729463129
# │   ├── dask-worker-space/
# │   │   ├── dask-worker-space/
# │   │   ├── worker-31wrsv82/
# │   │   ├── global.lock
# │   │   ├── purge.lock
# │   │   └── worker-31wrsv82.dirlock
# │   ├── R_fls.R
# │   ├── aux_functions.py
# │   ├── data_monitor.py
# │   ├── desktop.ini
# │   ├── df.pkl
# │   ├── fibonacci.py
# │   ├── operations.py
# │   ├── operations_priceadjustments.py
# │   ├── ppt_generator.py
# │   ├── strategy_monitor.py
# │   └── strats_signals.py
# ├── backtest/
# │   ├── examples/
# │   │   ├── simple_equity_bt.py
# │   │   └── simple_param_optimization.py
# │   ├── sandbox/
# │   │   ├── param_optimization_dourado_br.py
# │   │   ├── param_optimization_dracarys.py
# │   │   ├── param_optimization_dracarys_analyst_revisions.py
# │   │   ├── param_optimization_dracarys_analyst_sentiment.py
# │   │   ├── param_optimization_euz.py
# │   │   ├── param_optimization_jp.py
# │   │   ├── param_optimization_uk.py
# │   │   ├── param_optimization_us.py
# │   │   ├── param_optimization_viserion.py
# │   │   ├── param_optimization_viserion_euz.py
# │   │   ├── param_optimization_viserion_jp.py
# │   │   ├── param_optimization_viserion_long_only.py
# │   │   ├── param_optimization_viserion_uk.py
# │   │   └── simple_equity_bt.py
# │   ├── __init__.py
# │   └── backtest.py
# ├── bbg_api/
# │   ├── host/
# │   │   ├── main.py
# │   │   ├── registry_templates.py
# │   │   ├── request_models.py
# │   │   └── response_models.py
# │   ├── http_requests/
# │   │   ├── BDH.http
# │   │   ├── BDP.http
# │   │   └── BDP_BULK.http
# │   ├── __init__.py
# │   ├── client.py
# │   ├── constants.py
# │   ├── exceptions.py
# │   └── utils.py
# ├── bo/
# │   ├── procedures/
# │   │   ├── trade_allocation/
# │   │   ├── __init__.py
# │   │   └── check_result.py
# │   ├── tests/
# │   │   └── trade_allocation/
# │   └── __init__.py
# ├── connector/
# │   ├── mongo/
# │   │   ├── __init__.py
# │   │   ├── arctic_connector.py
# │   │   └── mongodb_connector.py
# │   ├── mssql/
# │   │   ├── __init__.py
# │   │   └── mssql_connector.py
# │   ├── postgre/
# │   │   ├── __init__.py
# │   │   └── postgre_connector.py
# │   ├── __init__.py
# │   ├── arcticdb.py
# │   └── generic.py
# ├── dashboard/
# │   ├── assets/
# │   │   └── styles.css
# │   ├── cache-directory/
# │   │   ├── 00398a743efad44e8b324dafd9d2f417
# │   │   ├── 009741d3899805a9d78f5fe81d2a77b7
# │   │   ├── 033a633cf2f14c7d086cec72b8a92574
# │   │   ├── 03bdb50e0bcfc64a8fe65f3372419cbb
# │   │   ├── 04b90ca16203dc9898344797d3178a28
# │   │   ├── 05656ab9a0ab6606012f37b35a1209e7
# │   │   ├── 05d691a78aec1fbacb4faf6f668a120e
# │   │   ├── 0657c6deedbffde19b69cadc63a9f22d
# │   │   ├── 085307a4b04c4859896f0c2942772d42
# │   │   ├── 0cc7cf808308c5eb94c456f9834fce1b
# │   │   ├── 0e2f850e9d9b0d257ce244060def6306
# │   │   ├── 0f0f3a65b8ace1618ea9cebd21e97192
# │   │   ├── 0fe8a170a98df62a9b534a78bfde4fd5
# │   │   ├── 136be3262279593807bdef23b44ca81d
# │   │   ├── 15c261e0fc9d0fd99609f7ffaba2e386
# │   │   ├── 16b376da371c27fdca5b4ea65fcd1072
# │   │   ├── 18df7dfe21e2865b42d7602b24696e02
# │   │   ├── 1cc8b8dad8eacc33c97c8470681d82b5
# │   │   ├── 1e4b960d3db375c455f03b45d199a415
# │   │   ├── 1fabab354c7febe8636c3c230d299084
# │   │   ├── 2029240f6d1128be89ddc32729463129
# │   │   ├── 21809f9f04dee48e50a53ca09351303c
# │   │   ├── 233fc30ecb2e08a5e1855a26bbdc3906
# │   │   ├── 23ac0583d9a9169dc078fd2fdaff5bf1
# │   │   ├── 2433aae09ae06ed66e061c7958183d12
# │   │   ├── 281ff9f84c5f9644e4df6c540a00fe78
# │   │   ├── 2904e91c16cf3abdc894df429aa0075b
# │   │   ├── 2c91ccc5f7700fa3d71938d034f6b230
# │   │   ├── 2dc2b7a1d234aa8eabcfb720d5191381
# │   │   ├── 2ded634b87d16bb1395ebdca6b2a3000
# │   │   ├── 371d88f4482021bd24b80c7d964b9031
# │   │   ├── 374181f27aa86ee585cf5b60f913511f
# │   │   ├── 3df9f513afdd6fb173aa40110b68cac7
# │   │   ├── 3e1155d241c9a8e3542c3f2fa615bb33
# │   │   ├── 446d10a9866aa7cb9e64944f3ad6364a
# │   │   ├── 462e7f71af899cdf71decff2a431dcaf
# │   │   ├── 48ed3433306de3abfdeaac6b6183056f
# │   │   ├── 4ae3327e3028fa6e1b2cd77031690f68
# │   │   ├── 4b52b591252d83abce9d741cf38ce0c4
# │   │   ├── 4f1fd79b34b8eac12e495bb8c284ddc9
# │   │   ├── 4f253589489307b91b30d011e5f4a12e
# │   │   ├── 525635adae5b15615330f7a021893b94
# │   │   ├── 52c20b72b4544a0179d54adef976e9c5
# │   │   ├── 55379ef8e62e6bb7df3d76ed2ca1a4bf
# │   │   ├── 596b38c60049ed805b57f5c5628e5a19
# │   │   ├── 5b1a1ff41d54ffb408afb669c30314fb
# │   │   ├── 5b46956256fd62dac9ccdd30278a1895
# │   │   ├── 5b993753e5c6c38e2d11ecc4b0062888
# │   │   ├── 623445b082522c1da667ad62f2273ca8
# │   │   ├── 63bd6ebb50f001a0e9da83c996406084
# │   │   ├── 64c579f45d3429cf1a5e9e96f6144b03
# │   │   ├── 69db8ec00648b532746ba418fbe31cb2
# │   │   ├── 6b7776b6661a367c68574a1024851628
# │   │   ├── 6c20dd92dac437ffc77e1f3167b1e13a
# │   │   ├── 6c4fa476372bda5224ca5a0a36a77c12
# │   │   ├── 6d6b1b1dc5889d649988808c260b0c1d
# │   │   ├── 6f006f08ae59196177a5fd953a69e587
# │   │   ├── 7320b2168dc8ed2bc26696cc9de8a218
# │   │   ├── 74945249e06133c286b255092770bd2a
# │   │   ├── 7518da90b6c7733f1861d8d5f28ac3c4
# │   │   ├── 783284a07f5cf7ac62e03b22eb2f3e48
# │   │   ├── 79d725be01b5f917e07e1ff7ddb5e641
# │   │   ├── 7c1df1a5b0676ab6b8cf7cf861f7a05d
# │   │   ├── 7d91cfaa32044141cd938935735d393f
# │   │   ├── 86a8253f03ef2652077d8107d622b46a
# │   │   ├── 86f480a93247f4957154938e9293ef2f
# │   │   ├── 88a469ccc5db38128d39c1e006eab6a9
# │   │   ├── 8a656e6bc1f084351d5b3e6b0a21c43a
# │   │   ├── 8c4cc3b4f874a18a937d360d3e7e9d8e
# │   │   ├── 8e1e4c1ba30a09ff609b5669371ce3b6
# │   │   ├── 906e35ef3e5209fc0617d5f8ad8dddd0
# │   │   ├── 9288c9f1876d5fcb3f9544f38f340478
# │   │   ├── 93c7e401de711dab4dd2fa67998f234d
# │   │   ├── 93ca30684b542b96f605bf37dc47daef
# │   │   ├── 9446eff85d0bf3e2a963cdeb2482b830
# │   │   ├── 97118a32599b7ad05cc52f0b9882ab6f
# │   │   ├── 9944b9c79ec18a490416b36de756ebe2
# │   │   ├── 9a43adfe10122b5cc903238b8786d89b
# │   │   ├── 9c5a770a270e8a110167e7690f19cf11
# │   │   ├── 9fa02f91299ad912d0cc7fe32bfef430
# │   │   ├── a16ef807ef53b7936cfc1dfb19437d03
# │   │   ├── a2f218fb8f72407860a6a439b68cacd2
# │   │   ├── a823c169b8342557a27e1b8f0734e986
# │   │   ├── aa55e50280c70fdc6497573fea89c187
# │   │   ├── aba28c6d320b68f8d316ab462062783a
# │   │   ├── ac5a3d4e1bf9f9e12596d136ec1c14e5
# │   │   ├── ac73d079938742109f425cbb80d6c9bd
# │   │   ├── af22e8275d97a9d7bf4238d8bf1b4216
# │   │   ├── b043a8cdbe8a5cfd229034fc4cf77979
# │   │   ├── b12f8943578221b2dc419446d98e1b93
# │   │   ├── b2990fe88a657ada7bde03ed006d960f
# │   │   ├── b417995df1e9d782d36f9bea7b669125
# │   │   ├── b49216488fcb0aa65067c87ee80b0209
# │   │   ├── b7c393bd6da7a4c05cb6fb9b27d5943b
# │   │   ├── b967323d9f7a6d72ce8663711c878092
# │   │   ├── b99ab276c3a1e04b9bcab71e9396d897
# │   │   ├── baf265b06b68cc66189089fd69b8604c
# │   │   ├── bb757e8a191de7b796b5260372a141d7
# │   │   ├── c02788a5be03aa980d43544a928b7116
# │   │   ├── c2b3362fc2e9755b004fba3b0855225b
# │   │   ├── c361a35ca063fa5d9d0d7e30eeb4d225
# │   │   ├── c443a1683cabb3077dba7b5886f4fd84
# │   │   ├── c5a8ea5b6fb093f760b6991525e3897a
# │   │   ├── c6690c1c17afeac960f2e30116feee46
# │   │   ├── c8151c3ddc809871df39883cc157f6f0
# │   │   ├── c8eb26be8405cadff29bdd1405f4ab62
# │   │   ├── c8ff42dc9aa2fa65b500d1b75d652af9
# │   │   ├── cd14550089e78c1afaf1aacfdc07f5ff
# │   │   ├── cd8b6446978ce37564a280069386531d
# │   │   ├── ceeccfa221e93cfd15d9d11e68081d83
# │   │   ├── cfe23226949c50be11949124bf07e2d1
# │   │   ├── d0a1662c2806b8edeeb7905b16565be5
# │   │   ├── d33c4acaa9c605c95223b27e8390eb5c
# │   │   ├── d6b500068c21ff75861bf1d9c0010bf4
# │   │   ├── d99688c55bd01dbe30b0b7aab8c07d35
# │   │   ├── daf2af807933f872b49cdb86d2326479
# │   │   ├── db05aa011f5c61e4c99ee5f5b2b9453b
# │   │   ├── dc2a28ddaec5be17237b2c95d7846d27
# │   │   ├── dd47f4895409de3d1b4d536c6561c99d
# │   │   ├── dd672a98270ee4803c362c8d570db185
# │   │   ├── dfecf8782b3db9259a4d474113f5a158
# │   │   ├── e14d40e0f79377ef68c31a1211f227d7
# │   │   ├── e3206ac2a014ec107be2b51a2586fa72
# │   │   ├── e41333af90adb71a327a0558ac142901
# │   │   ├── e418548a44d60048ce5c579a2473977d
# │   │   ├── e4548e526fbeebb1b96102c6c40c144d
# │   │   ├── e473fdb20756cbf2f8682c14852fa840
# │   │   ├── e4f0976500d6e627ceb34b1f45c2ac98
# │   │   ├── e5f94707c69f77b1eb84e1af2322e734
# │   │   ├── e705657471333f5e7c6663a5d0f2afd3
# │   │   ├── e71e8efe759e613b574a0d5c43a2f01a
# │   │   ├── e8d8491ff6f3f8818305ae7c85ac781f
# │   │   ├── e92e32b3105aa5e6f1dbb20f080fdf2e
# │   │   ├── e95ace2331b0facc9ca28dc0789166e1
# │   │   ├── eb39a67f3d91d7fdf9d53042cbf15b24
# │   │   ├── eb7ca9a317dea97def35e71267cb7380
# │   │   ├── ebbe1ac4e574e70aaeeaa85e554b3810
# │   │   ├── ec60668afa3fd6f81d3af36ab3eb8318
# │   │   ├── ee2127978b2768fb42afeacd2fc518d4
# │   │   ├── f062e42f0ad6f95fce4c47fc6db42dd2
# │   │   ├── f0721d9c5a4fd458d7da94839b56e4b3
# │   │   ├── f2a78cbab510b8099a6d374df65de422
# │   │   ├── f2f3281269a38a47dc028ff21ab511ee
# │   │   ├── f36ee12b9e4376463eafd9aef1454cfe
# │   │   ├── f5271810c9e026dd3b46da6350c4face
# │   │   ├── fdc5c1cd38b1bd615b70bd06f376245f
# │   │   └── ffbfe6af85b9402826b9488ec73ffa80
# │   ├── callbacks/
# │   │   ├── __init__.py
# │   │   ├── apresentacao.py
# │   │   ├── check_result_history.py
# │   │   ├── cost_conciliation.py
# │   │   ├── evolution.py
# │   │   ├── evolution_check_result_diff.py
# │   │   ├── layout.py
# │   │   ├── pnl.py
# │   │   ├── pnl_period.py
# │   │   ├── position.py
# │   │   └── table.py
# │   ├── common/
# │   │   ├── __init__.py
# │   │   ├── base_queries.py
# │   │   ├── constants.py
# │   │   ├── pnl.py
# │   │   ├── position_notional.py
# │   │   ├── position_pct.py
# │   │   └── position_quantity.py
# │   ├── components/
# │   │   ├── __init__.py
# │   │   └── table.py
# │   ├── controllers/
# │   │   ├── __init__.py
# │   │   ├── apresentacao.py
# │   │   ├── check_result.py
# │   │   ├── check_result_history.py
# │   │   ├── cost_conciliation.py
# │   │   ├── evolution.py
# │   │   ├── evolution_check_result.py
# │   │   ├── gerencial.py
# │   │   ├── home.py
# │   │   ├── layout.py
# │   │   ├── notional.py
# │   │   ├── pnl.py
# │   │   ├── position.py
# │   │   ├── price.py
# │   │   └── risk.py
# │   ├── helpers/
# │   │   ├── __init__.py
# │   │   ├── column_renaming.py
# │   │   ├── format_table.py
# │   │   ├── gaia_k15_helper.py
# │   │   ├── pivot_table.py
# │   │   └── tab_helper.py
# │   ├── layout/
# │   │   └── layout.py
# │   ├── pages/
# │   │   ├── apresentacao.py
# │   │   ├── check_result.py
# │   │   ├── check_result_history.py
# │   │   ├── cost_conciliation.py
# │   │   ├── evolution.py
# │   │   ├── evolution_check_result_diff.py
# │   │   ├── gerencial.py
# │   │   ├── home.py
# │   │   ├── month_pnl.py
# │   │   ├── pnl.py
# │   │   ├── pnl_period.py
# │   │   ├── position.py
# │   │   ├── price.py
# │   │   ├── risk.py
# │   │   ├── semester_pnl.py
# │   │   └── week_pnl.py
# │   ├── scripts/
# │   │   ├── Convert o pickle.ipynb
# │   │   ├── arctic_lib_configs_test.py
# │   │   ├── aws_test.py
# │   │   ├── calendar_lmes_update.py
# │   │   ├── carry-di-result.py
# │   │   ├── create_previous_check_result.py
# │   │   ├── create_previous_cost_conciliation.py
# │   │   ├── create_previous_results.py
# │   │   ├── delete_previous_arcticdb_versions.py
# │   │   ├── dumb_old_arctic_new.py
# │   │   ├── email_checker.py
# │   │   ├── include_fields_wealthlab.py
# │   │   ├── make_gerencial_usd.py
# │   │   ├── new_bbg_eod_sandbox.py
# │   │   ├── pl_funds_dump.py
# │   │   ├── read_html.py
# │   │   ├── register_metadata_diff.py
# │   │   └── testing.py
# │   ├── services/
# │   │   ├── __init__.py
# │   │   └── verify_exercised_options.py
# │   ├── __init__.py
# │   ├── app.py
# │   ├── auth.py
# │   ├── extensions.py
# │   ├── index.py
# │   ├── metadata-debug.py
# │   └── readme.txt
# ├── dask-worker-space/
# │   ├── global.lock
# │   └── purge.lock
# ├── db/
# │   ├── dataloader/
# │   │   ├── models/
# │   │   ├── __init__.py
# │   │   └── dataloader.py
# │   ├── metadata/
# │   │   ├── models/
# │   │   ├── __init__.py
# │   │   ├── document.py
# │   │   └── exceptions.py
# │   ├── models/
# │   │   ├── middle_office/
# │   │   ├── __init__.py
# │   │   ├── k15.py
# │   │   ├── kptl_bo.py
# │   │   ├── kptl_corp.py
# │   │   ├── log.py
# │   │   ├── mapper.py
# │   │   ├── metadata.py
# │   │   ├── routine.py
# │   │   └── table.py
# │   ├── scratches/
# │   │   └── arcticDB.py
# │   ├── tests/
# │   │   ├── connector/
# │   │   ├── metadata/
# │   │   ├── models/
# │   │   └── test_utils.py
# │   ├── __init__.py
# │   ├── exceptions.py
# │   ├── factset_pickle_utils.py
# │   ├── model_utils.py
# │   └── utils.py
# ├── docs/
# │   ├── K15API/
# │   │   ├── source/
# │   │   ├── Makefile
# │   │   ├── make.bat
# │   │   ├── make_full.bat
# │   │   └── readme.txt
# │   ├── Tick History API/
# │   ├── Trade Allocation Problem/
# │   │   ├── Trade Allocation Problem v1.docx
# │   │   └── Trade Allocation Problem.docx
# │   └── Git Conventions.docx
# ├── finmath/
# │   ├── tests/
# │   │   └── test_stats.py
# │   ├── __init__.py
# │   ├── plots.py
# │   ├── pricing.py
# │   ├── stats.py
# │   └── style.mplstyle
# ├── log/
# │   ├── tests/
# │   │   └── quicktest_routine_logger.py
# │   ├── __init__.py
# │   ├── bbg_api_logger.py
# │   ├── colored_log.py
# │   ├── google_chat_logger.py
# │   ├── mongo_logger.py
# │   ├── routine_logger.py
# │   ├── simple_logger.py
# │   ├── telegram_logger.py
# │   └── utils.py
# ├── procedures/
# │   ├── _routine_call_graphs/
# │   │   └── factset_japan_daily.py
# │   ├── debug/
# │   │   ├── debug_bbg_eod.py
# │   │   ├── debug_bbg_eod_selected.py
# │   │   ├── dev_debug_bbg_eod.py
# │   │   ├── dev_debug_bbg_eod_selected.py
# │   │   └── script_intraday_full_hist.py
# │   ├── jn/
# │   │   ├── Studies/
# │   │   ├── iframe_figures/
# │   │   ├── Cash Cost.ipynb
# │   │   ├── Check DB Intraday Equity.ipynb
# │   │   ├── Check DB Intraday.ipynb
# │   │   ├── Check Result Semester.ipynb
# │   │   ├── Compare Series - Intraday.ipynb
# │   │   ├── Descolamento Gaia.ipynb
# │   │   ├── GSISI87E vs EFI EW-LO Port.ipynb
# │   │   ├── Hedge Net Exposure.ipynb
# │   │   └── Internal Event Driven IBOTZ.ipynb
# │   ├── procedure_groups/
# │   │   ├── __init__.py
# │   │   ├── arcticdb.py
# │   │   ├── data_services.py
# │   │   ├── io.py
# │   │   ├── metadata.py
# │   │   ├── middle_office.py
# │   │   ├── other.py
# │   │   ├── strategy.py
# │   │   ├── synthetic.py
# │   │   └── trading.py
# │   ├── procedures/
# │   │   ├── download_benzinga_api_data.py
# │   │   ├── download_refinitiv_intraday_for_incomplete_series.py
# │   │   ├── download_refinitiv_intraday_full_hist.py
# │   │   ├── generate_resampled_and_rolled_intraday_series.py
# │   │   ├── generate_resampled_equity.py
# │   │   ├── ibotz_internals.py
# │   │   └── refinitiv_store_data_from_extracted_file.py
# │   ├── resources/
# │   │   ├── K15 Routine Watchdog.cmd
# │   │   ├── windows-routine-example-py10.xml
# │   │   └── windows-routine-example-py37.xml
# │   ├── __init__.py
# │   ├── _exec_routine_windows_task_scheduler.py
# │   ├── _test_exec_routine_windows_task_scheduler.py
# │   ├── generic.py
# │   └── routine_watchdog.py
# ├── reports/
# │   ├── descolamento_report/
# │   │   ├── __init__.py
# │   │   ├── report_generator.py
# │   │   ├── template.css
# │   │   └── template.html
# │   └── __init__.py
# ├── scheduler/
# │   ├── dask-worker-space/
# │   │   ├── dask-worker-space/
# │   │   ├── worker-jrl3be1i/
# │   │   ├── worker-x1p1i2ia/
# │   │   ├── global.lock
# │   │   ├── purge.lock
# │   │   ├── worker-jrl3be1i.dirlock
# │   │   └── worker-x1p1i2ia.dirlock
# │   ├── __init__.py
# │   ├── main.py
# │   └── test.py
# ├── strategy/
# │   ├── strategies/
# │   │   ├── balerion/
# │   │   ├── dourado/
# │   │   ├── dracarys/
# │   │   ├── indexrebal/
# │   │   ├── viserion/
# │   │   ├── __init__.py
# │   │   └── drogon.py
# │   ├── templates/
# │   │   ├── single_stock_event_driven.py
# │   │   └── single_stocks.py
# │   ├── __init__.py
# │   ├── constants.py
# │   ├── exceptions.py
# │   ├── strategy_aggregator.py
# │   └── strategy_base.py
# ├── tests/
# │   ├── lab_script.py
# │   ├── pytorch_simple_comparison.py
# │   └── tensor_simple_example.py
# ├── utils/
# │   ├── tests/
# │   │   ├── quicktest_tt_api.py
# │   │   ├── test_calendars.py
# │   │   ├── test_files.py
# │   │   ├── test_task.py
# │   │   └── tt2.xlsx
# │   ├── __init__.py
# │   ├── argparser.py
# │   ├── calendar.py
# │   ├── class_utils.py
# │   ├── constants.py
# │   ├── date.py
# │   ├── email_sender.py
# │   ├── exceptions.py
# │   ├── files.py
# │   ├── general.py
# │   ├── google_chat_api.py
# │   ├── ibotz.py
# │   ├── jupyter_notebook.py
# │   ├── middle_office.py
# │   ├── numpy_utils.py
# │   ├── pandas_utils.py
# │   ├── plotly_utils.py
# │   ├── pointer.py
# │   ├── task.py
# │   ├── tt_api.py
# │   ├── typecheck.py
# │   └── xlui.py
# ├── _____teste.py
# ├── _____teste2.py
# ├── bfg-1.14.0.jar
# ├── blp.txt
# ├── desktop.ini
# ├── index
# └── requirements.txt
#
# === WORKSPACE STATS ===
# {
#   "total_files": 870,
#   "total_size_mb": 165.42,
#   "top_extensions": {
#     ".py": 584,
#     "no_extension": 151,
#     ".rst": 36,
#     ".html": 29,
#     ".ipynb": 16,
#     ".lock": 12,
#     ".dirlock": 10,
#     ".txt": 4,
#     ".ini": 4,
#     ".xml": 4
#   }
# }
