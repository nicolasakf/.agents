# %% [markdown]
# # Workspace Explorer

# %% [markdown]
# ## Description
# Explores the local workspace filesystem, analyzes project structure, searches for files or text, and summarizes the workspace layout. Use when you need to understand the project directory structure, locate specific files or configurations, find where variables/functions are defined, or get a general lay of the land in an unfamiliar repository.

# %% [markdown]
# ## System Prompt
# You are an autonomous workspace explorer sub-agent. Your goal is to rapidly and accurately comprehend the structure, contents, and purpose of the local project directory.
#
# **Expected Input:**
# The parent agent will provide a description of what to look for (e.g., 'summarize the project structure', 'find where the database connection is established', or 'list all markdown files').
#
# **Capabilities & Best Practices:**
# 1. **Python Utilities First:** Use the `WorkspaceExplorer` Python class provided in the scratchpad cells below. It is designed to safely summarize large directories, respect common ignore patterns (like `node_modules` or `.git`), and avoid context-window overflows.
# 2. **Avoid Massive Outputs:** Never run unrestricted `find .` or `tree` commands, and avoid printing entire large files. Always use depth limits (`max_depth`) and read snippets.
# 3. **Fallback to Bash:** Use the `bash` tool (with `rg`, `fd`, `find`) if you need complex command-line searches not covered by the Python utilities.
# 4. **Read Files:** Use the `read_file` tool to inspect the exact contents of files once you locate them.
# 5. **Read-Only:** You are strictly read-only. Do not modify, move, or delete files.
#
# **Final Output:**
# Return a concise, structured markdown summary to the parent agent. Include the most relevant file paths, a high-level project architecture, and direct answers to the parent's specific queries.

# %%
import os
print('This is your current working directoy:', os.getcwd())
# Out:
# This is your current working directoy: /Users/nicolasfonteyne/.agents/subagents/tmp/workspace-explorer

# %%
# Reusable Workspace Explorer Python Utility
import re
from pathlib import Path
from collections import Counter
import json

class WorkspaceExplorer:
    def __init__(self, root="."):
        self.root = Path(root).resolve()
        # Common directories and files to ignore to keep context clean
        self.ignore_dirs = {'.git', 'node_modules', 'venv', '.venv', 'env', '__pycache__', '.pytest_cache', 'build', 'dist', '.next', 'coverage', '.idea', '.vscode'}
        self.ignore_exts = {'.pyc', '.pdf', '.png', '.jpg', '.jpeg', '.gif', '.zip', '.tar', '.gz', '.mp4', '.sqlite3', '.db', '.DS_Store'}

    def _is_ignored(self, path: Path) -> bool:
        if path.name in self.ignore_dirs:
            return True
        if path.suffix.lower() in self.ignore_exts:
            return True
        return False

    def get_tree(self, max_depth=2) -> str:
        """Generates a clean tree view of the directory up to max_depth."""
        tree_str = []
        
        def walk(current_path, prefix="", depth=0):
            if depth > max_depth:
                return
            try:
                entries = sorted(list(current_path.iterdir()), key=lambda x: (not x.is_dir(), x.name))
            except PermissionError:
                return
                
            entries = [e for e in entries if not self._is_ignored(e) and not e.name.startswith('.')]
            
            for i, entry in enumerate(entries):
                is_last = (i == len(entries) - 1)
                connector = "└── " if is_last else "├── "
                tree_str.append(f"{prefix}{connector}{entry.name}{'/' if entry.is_dir() else ''}")
                
                if entry.is_dir():
                    extension = "    " if is_last else "│   "
                    walk(entry, prefix + extension, depth + 1)
                    
        tree_str.append(f"📂 {self.root.name}/")
        walk(self.root)
        return "\n".join(tree_str)

    def get_stats(self) -> dict:
        """Returns a dictionary of file counts by extension and total size."""
        ext_counts = Counter()
        total_size = 0
        file_count = 0
        
        for dirpath, dirnames, filenames in os.walk(self.root):
            # Modify dirnames in-place to skip ignored directories
            dirnames[:] = [d for d in dirnames if d not in self.ignore_dirs and not d.startswith('.')]
            
            for f in filenames:
                p = Path(dirpath) / f
                if self._is_ignored(p) or f.startswith('.'):
                    continue
                ext = p.suffix.lower() or 'no_extension'
                ext_counts[ext] += 1
                file_count += 1
                try:
                    total_size += p.stat().st_size
                except OSError:
                    pass
                    
        return {
            "total_files": file_count,
            "total_size_mb": round(total_size / (1024 * 1024), 2),
            "top_extensions": dict(ext_counts.most_common(10))
        }
        
    def find_content(self, pattern: str, max_results=15) -> list:
        """Searches for a regex pattern in files, returning a list of matched lines."""
        matches = []
        try:
            regex = re.compile(pattern, re.IGNORECASE)
        except re.error:
            return ["Invalid regex pattern"]
            
        for dirpath, dirnames, filenames in os.walk(self.root):
            dirnames[:] = [d for d in dirnames if d not in self.ignore_dirs and not d.startswith('.')]
            
            for f in filenames:
                if len(matches) >= max_results:
                    return matches
                    
                p = Path(dirpath) / f
                if self._is_ignored(p) or f.startswith('.'):
                    continue
                    
                try:
                    with open(p, 'r', encoding='utf-8', errors='ignore') as file:
                        for line_no, line in enumerate(file, 1):
                            if regex.search(line):
                                matches.append(f"{p.relative_to(self.root)}:{line_no}: {line.strip()[:120]}")
                                if len(matches) >= max_results:
                                    break
                except Exception:
                    pass
        return matches

# %%
# Run this cell to instantly get a high-level overview of the project structure and stats
import json
workspace_path = "/Users/nicolasfonteyne/Github_nicolasakf/Orion"
explorer = WorkspaceExplorer(root=workspace_path)

print(f"=== WORKSPACE TREE ({workspace_path}) ===")
print(explorer.get_tree(max_depth=2))

print("\n=== WORKSPACE STATS ===")
print(json.dumps(explorer.get_stats(), indent=2))
# Out:
# === WORKSPACE TREE (/Users/nicolasfonteyne/Github_nicolasakf/Orion) ===
# 📂 Orion/
# ├── app/
# │   ├── api/
# │   │   ├── account/
# │   │   ├── admin/
# │   │   ├── auth/
# │   │   ├── billing/
# │   │   ├── bug-reports/
# │   │   ├── chat/
# │   │   ├── credentials/
# │   │   ├── dev-log/
# │   │   ├── models/
# │   │   ├── search/
# │   │   ├── stripe/
# │   │   └── waitlist/
# │   ├── auth/
# │   │   └── reset-password/
# │   ├── globals.css
# │   ├── layout.tsx
# │   └── page.tsx
# ├── components/
# │   ├── auth/
# │   │   ├── auth-dialog.tsx
# │   │   └── session-provider.tsx
# │   ├── common/
# │   │   ├── alert-card.tsx
# │   │   ├── auto-run-confirm-dialog.tsx
# │   │   ├── confirm-popover.tsx
# │   │   ├── error-card.tsx
# │   │   ├── file-icon.tsx
# │   │   ├── kernel-icon.tsx
# │   │   ├── keyboard-icons.tsx
# │   │   ├── loading-message.tsx
# │   │   ├── no-kernel-prompt.tsx
# │   │   └── toolbar-button.tsx
# │   ├── left-sidebar/
# │   │   ├── file-tree.tsx
# │   │   ├── left-sidebar.tsx
# │   │   ├── search-form.tsx
# │   │   ├── sticky-accordion-header-with-toolbar.tsx
# │   │   ├── variable-detail-dialog.tsx
# │   │   ├── variables-panel.tsx
# │   │   ├── workspace-picker.tsx
# │   │   └── workspace-search.tsx
# │   ├── mobile/
# │   │   ├── mobile-menu.tsx
# │   │   └── mobile-toolbar.tsx
# │   ├── notebook/
# │   │   ├── renderers/
# │   │   ├── table/
# │   │   ├── cell-context-menu.tsx
# │   │   ├── cell-output-toolbar.tsx
# │   │   ├── chart-renderer.tsx
# │   │   ├── code-renderer.tsx
# │   │   ├── kernel-dialogs.tsx
# │   │   ├── markdown-renderer.tsx
# │   │   ├── notebook-cell.tsx
# │   │   ├── notebook-editor.tsx
# │   │   ├── notebook-minimap-panel.tsx
# │   │   ├── notebook-minimap.ts
# │   │   ├── output-context-menu.tsx
# │   │   ├── output-presentation.ts
# │   │   ├── output-renderer.tsx
# │   │   └── utils.ts
# │   ├── right-sidebar/
# │   │   ├── __tests__/
# │   │   ├── assistant-message.tsx
# │   │   ├── chat-body.tsx
# │   │   ├── chat-markdown-renderer.tsx
# │   │   ├── chat-textbox.tsx
# │   │   ├── chat-toolbar.tsx
# │   │   ├── code-block.tsx
# │   │   ├── context-usage-pill.tsx
# │   │   ├── delegate-invocation-card.tsx
# │   │   ├── model-settings-popover.tsx
# │   │   ├── model-upgrade-card.tsx
# │   │   ├── right-sidebar.tsx
# │   │   ├── scroll-edge-gradient.tsx
# │   │   ├── slash-commands.ts
# │   │   ├── streaming-markdown.ts
# │   │   ├── thinking-block.tsx
# │   │   ├── tool-invocation-card.tsx
# │   │   ├── tool-invocation-helpers.ts
# │   │   ├── tool-invocation-result-display.ts
# │   │   ├── types.ts
# │   │   └── user-message.tsx
# │   ├── settings/
# │   │   └── settings-provider.tsx
# │   ├── settings-dialog/
# │   │   ├── account-tab.tsx
# │   │   ├── appearance-tab.tsx
# │   │   ├── billing-tab.tsx
# │   │   ├── models-tab.tsx
# │   │   ├── providers-tab.tsx
# │   │   ├── role-combobox.tsx
# │   │   ├── settings-dialog.tsx
# │   │   ├── settings-sidebar.tsx
# │   │   ├── storage-tab.tsx
# │   │   └── types.ts
# │   ├── terminal/
# │   │   ├── terminal-panel.tsx
# │   │   └── xterm-terminal.tsx
# │   ├── ui/
# │   │   ├── accordion.tsx
# │   │   ├── alert-dialog.tsx
# │   │   ├── alert.tsx
# │   │   ├── aspect-ratio.tsx
# │   │   ├── avatar.tsx
# │   │   ├── badge.tsx
# │   │   ├── breadcrumb.tsx
# │   │   ├── button.tsx
# │   │   ├── calendar.tsx
# │   │   ├── card.tsx
# │   │   ├── carousel.tsx
# │   │   ├── chart.tsx
# │   │   ├── checkbox.tsx
# │   │   ├── collapsible.tsx
# │   │   ├── command.tsx
# │   │   ├── context-menu.tsx
# │   │   ├── dialog.tsx
# │   │   ├── drawer.tsx
# │   │   ├── dropdown-menu.tsx
# │   │   ├── form.tsx
# │   │   ├── hover-card.tsx
# │   │   ├── input-otp.tsx
# │   │   ├── input.tsx
# │   │   ├── label.tsx
# │   │   ├── menubar.tsx
# │   │   ├── navigation-menu.tsx
# │   │   ├── pagination.tsx
# │   │   ├── popover.tsx
# │   │   ├── progress.tsx
# │   │   ├── radio-group.tsx
# │   │   ├── resizable.tsx
# │   │   ├── scroll-area.tsx
# │   │   ├── select.tsx
# │   │   ├── separator.tsx
# │   │   ├── sheet.tsx
# │   │   ├── sidebar.tsx
# │   │   ├── skeleton.tsx
# │   │   ├── slider.tsx
# │   │   ├── sonner.tsx
# │   │   ├── switch.tsx
# │   │   ├── table.tsx
# │   │   ├── tabs.tsx
# │   │   ├── textarea.tsx
# │   │   ├── toast.tsx
# │   │   ├── toaster.tsx
# │   │   ├── toggle-group.tsx
# │   │   ├── toggle.tsx
# │   │   ├── tooltip.tsx
# │   │   ├── use-mobile.tsx
# │   │   └── use-toast.ts
# │   ├── editor-reload-dialog.tsx
# │   ├── editor.tsx
# │   ├── filepath-breadcrumb.tsx
# │   ├── monaco-editor.tsx
# │   ├── settings-menu.tsx
# │   ├── theme-provider.tsx
# │   ├── version-switcher.tsx
# │   └── welcome-instructions-card.tsx
# ├── contexts/
# │   ├── mobile-layout-context.tsx
# │   └── open-settings-context.tsx
# ├── docs/
# │   ├── file_complexity_analysis.ipynb
# │   ├── notebook-plotly-regression-checklist.md
# │   ├── stripe-billing-test-checklist.md
# │   └── subscription-test-cases.md
# ├── hooks/
# │   ├── use-jupyter-shell-ready.ts
# │   ├── use-kernel-variables.ts
# │   ├── use-orion-settings.ts
# │   ├── use-platform.ts
# │   ├── use-profile-tier.ts
# │   ├── use-toast.ts
# │   └── use-user.ts
# ├── lib/
# │   ├── agent/
# │   │   ├── docs/
# │   │   ├── prompts/
# │   │   ├── subagents/
# │   │   ├── tools/
# │   │   ├── README.md
# │   │   ├── agent-system-prompt.ts
# │   │   ├── assistant-provider.tsx
# │   │   ├── context-manager.ts
# │   │   ├── context-optimizer.ts
# │   │   ├── cost-calculator.ts
# │   │   ├── index.ts
# │   │   ├── kernel-sidecar.ts
# │   │   ├── model-gateway-types.ts
# │   │   ├── model-gateway.ts
# │   │   ├── read-only-bash-guard.ts
# │   │   ├── runtime-store.ts
# │   │   ├── token-budget.ts
# │   │   ├── tool-approval.ts
# │   │   ├── tool-output-guard.ts
# │   │   └── tool-schemas.ts
# │   ├── auth/
# │   │   └── check-admin.ts
# │   ├── billing/
# │   │   ├── __tests__/
# │   │   ├── app-url.ts
# │   │   ├── billing-portal-configuration.ts
# │   │   ├── find-orion-subscription.ts
# │   │   ├── reset-profile-billing.ts
# │   │   ├── schedule-paid-tier-change.ts
# │   │   ├── stripe-price-map.ts
# │   │   ├── subscription-cancellation.ts
# │   │   ├── subscription-schedule-state.ts
# │   │   ├── subscription-sync.ts
# │   │   └── tier-entitlements.ts
# │   ├── chat/
# │   │   ├── chat-session.ts
# │   │   ├── chat-storage.ts
# │   │   └── compaction-client.ts
# │   ├── credentials/
# │   │   └── chatgpt-oauth.ts
# │   ├── kernel/
# │   │   ├── kernel-service.ts
# │   │   └── kernel-storage.ts
# │   ├── logging/
# │   │   ├── console-logger.ts
# │   │   ├── dev-logger-client.ts
# │   │   └── dev-logger.ts
# │   ├── notebook/
# │   │   ├── __tests__/
# │   │   ├── mime-registry/
# │   │   ├── cell-executor.ts
# │   │   ├── notebook-parser.ts
# │   │   └── table-extractor.ts
# │   ├── settings/
# │   │   ├── defaults.ts
# │   │   ├── index.ts
# │   │   ├── legacy.ts
# │   │   ├── merge.ts
# │   │   ├── migrations.ts
# │   │   ├── project-file-storage.ts
# │   │   ├── project-handle-storage.ts
# │   │   ├── schema.ts
# │   │   └── user-storage.ts
# │   ├── shell/
# │   │   ├── system-commands/
# │   │   ├── index.ts
# │   │   ├── terminal-executor.ts
# │   │   ├── terminal-pool.ts
# │   │   └── types.ts
# │   ├── skills/
# │   │   ├── builtin/
# │   │   ├── builtin-skills.ts
# │   │   ├── parse-frontmatter.ts
# │   │   ├── skill-registry.ts
# │   │   └── types.ts
# │   ├── stripe/
# │   │   └── server.ts
# │   ├── supabase/
# │   │   ├── client.ts
# │   ├── 1777039982010.log
# │   ├── 1777044129439.log
# │   ├── 1777044371916.log
# │   ├── 1777049161130.log
# │   ├── 1777049712336.log
# │   ├── 1777049828192.log
# │   ├── 1777049966318.log
# │   ├── 1777058295496.log
# │   ├── 1777147977105.log
# │   ├── 1777152582969.log
# │   ├── 1777211525655.log
# │   ├── 1777211767655.log
# │   ├── 1777213334273.log
# │   ├── 1777246079036.log
# │   ├── 1777297245563-explore#1.log
# │   ├── 1777297245563.log
# │   ├── 1777297777904.log
# │   ├── 1777317160440.log
# │   ├── 1777317669855.log
# │   ├── 1777319010688.log
# │   ├── 1777319148664.log
# │   ├── 1777319411416.log
# │   ├── 1777319874738.log
# │   ├── 1777319949261.log
# │   ├── 1777320747007.log
# │   ├── 1777326041041.log
# │   ├── 1777413484301.log
# │   ├── 1777413856922.log
# │   ├── 1777416553962.log
# │   ├── 1777418703045.log
# │   ├── 1777418877190.log
# │   ├── 1777472896396.log
# │   ├── 1777473612871.log
# │   ├── 1777477859103.log
# │   ├── 1777477949295.log
# │   ├── 1777478118382.log
# │   ├── 1777478186959.log
# │   ├── 1777750924663.log
# │   ├── 1777756295186.log
# │   ├── 1777756603167.log
# │   ├── 1777756788372.log
# │   ├── 1777764280764.log
# │   ├── 1777817533845.log
# │   ├── 1777830318447.log
# │   ├── 1777833379648.log
# │   ├── 1777834562074.log
# │   ├── 1777840242436.log
# │   ├── 1777859193025.log
# │   ├── 1777915168322.log
# │   ├── 1777920164310.log
# │   ├── 1778010024181.log
# │   ├── 1778013987288-workspace-explorer#1.log
# │   ├── 1778013987288.log
# │   ├── 1778014396103.log
# │   ├── 1778017675906.log
# │   ├── 1778017962444.log
# │   ├── 1778018132540.log
# │   ├── 1778018165917.log
# │   ├── 1778018320564.log
# │   ├── 1778018335780.log
# │   ├── 1778018442773.log
# │   ├── 1778018487715.log
# │   ├── 1778022822060-workspace-explorer#1.log
# │   ├── 1778022822060.log
# │   ├── 1778030656403-workspace-explorer#1.log
# │   └── 1778030656403.log
# ├── private/
# │   ├── mercury_account_monitoring.ipynb
# │   ├── model_prices_report.ipynb
# │   └── orion_activity_monitor.ipynb
# ├── public/
# │   ├── assets/
# │   │   ├── Orion Logo_Black 3D .svg
# │   │   ├── Orion Logo_Black.svg
# │   │   ├── Orion Logo_White 3D.svg
# │   │   └── Orion Logo_White.svg
# │   ├── docs/
# │   │   ├── chatgpt-codex-device-authorization.md
# │   │   ├── jupyter-hidden-folders-and-skills.md
# │   │   └── plotly-version-compatibility.md
# │   ├── test-files/
# │   │   ├── assets/
# │   │   ├── corrupted/
# │   │   ├── example.py
# │   │   ├── geojson-extension.ipynb
# │   │   ├── matplotlib_gallery.ipynb
# │   │   ├── mime_types_uncovered.ipynb
# │   │   ├── output_renderer_fixtures.ipynb
# │   │   ├── plotly_test.ipynb
# │   │   ├── table-extractor-test-dfs.ipynb
# │   │   ├── text_outputs_demo.ipynb
# │   │   └── vdom-extension.ipynb
# │   ├── test-prompts/
# │   │   ├── bash-await-command.md
# │   │   ├── boston-housing.md
# │   │   ├── heart-disease.md
# │   │   ├── shell-glob-grep.md
# │   │   └── shell-terminal.md
# │   ├── placeholder-logo.svg
# │   └── placeholder.svg
# ├── scripts/
# │   └── stripe-setup.ts
# ├── supabase/
# │   ├── migrations/
# │   │   ├── 20240101000000_init.sql
# │   │   ├── 20251211000001_create_models_table.sql
# │   │   ├── 20251212000000_refactor_models_and_chat_usage.sql
# │   │   ├── 20251220000000_update_models_and_add_xai.sql
# │   │   ├── 20251220000001_add_profile_trigger.sql
# │   │   ├── 20251220000002_add_token_columns_to_model_usage.sql
# │   │   ├── 20251220000003_add_model_usage_insert_policy.sql
# │   │   ├── 20260210000000_add_gpt53_and_opus46.sql
# │   │   ├── 20260210000001_waitlisted_tier_and_restrictions.sql
# │   │   ├── 20260213000000_remove_waitlisted_tier_add_waitlist_table.sql
# │   │   ├── 20260213000001_create_admin_api_keys.sql
# │   │   ├── 20260224000000_add_profile_name_role.sql
# │   │   ├── 20260225000000_add_gemini31_sonnet46_opus46_gpt53.sql
# │   │   ├── 20260226000000_create_model_request_table.sql
# │   │   ├── 20260304000000_add_models_grok3_gemini31flashlite_o3mini.sql
# │   │   ├── 20260304000001_update_google_models_remove_preview.sql
# │   │   ├── 20260305000000_add_gpt54.sql
# │   │   ├── 20260306100000_create_search_usage_table.sql
# │   │   ├── 20260306100001_replace_search_usage_with_counter.sql
# │   │   ├── 20260308000000_add_cost_usd_to_model_usage.sql
# │   │   ├── 20260308000001_add_long_context_pricing_to_models.sql
# │   │   ├── 20260310000000_add_registry_only_models.sql
# │   │   ├── 20260310100000_add_pinned_by_default_to_models.sql
# │   │   ├── 20260311000000_create_bug_reports_table.sql
# │   │   ├── 20260316000000_create_chat_session_table.sql
# │   │   ├── 20260316000001_add_status_to_bug_reports.sql
# │   │   ├── 20260316000002_remove_long_context_premium_for_claude46.sql
# │   │   ├── 20260405000000_add_gemma4.sql
# │   │   ├── 20260405000001_add_gpt54_mini_nano_grok420.sql
# │   │   ├── 20260411000000_add_is_byok_to_model_usage.sql
# │   │   ├── 20260411000001_add_go_tier.sql
# │   │   ├── 20260412000000_add_billing_subscriptions_and_guard_profile_billing_fields.sql
# │   │   ├── 20260412000001_add_go_trial_used_to_profiles.sql
# │   │   ├── 20260412000002_add_cancel_at_to_billing_subscriptions.sql
# │   │   ├── 20260413000000_add_scheduled_downgrade_to_billing_subscriptions.sql
# │   │   ├── 20260416100000_add_claude_opus_4_7.sql
# │   │   └── 20260426100000_add_gpt55.sql
# │   ├── scripts/
# │   │   ├── gen_types.sh
# │   │   └── reset_db.sh
# │   └── schema.sql
# ├── types/
# │   └── markdown.d.ts
# ├── AGENTS.md
# ├── CLAUDE.md
# ├── README.md
# ├── components.json
# ├── middleware.ts
# ├── next-env.d.ts
# ├── next.config.mjs
# ├── package-lock.json
# ├── package.json
# ├── postcss.config.mjs
# ├── tailwind.config.ts
# ├── tsconfig.json
# └── tsconfig.tsbuildinfo
#
# === WORKSPACE STATS ===
# {
#   "total_files": 798,
#   "total_size_mb": 248.34,
#   "top_extensions": {
#     ".log": 377,
#     ".ts": 171,
#     ".tsx": 154,
#     ".sql": 38,
#     ".md": 25,
#     ".ipynb": 16,
#     ".svg": 6,
#     ".json": 4,
#     ".mjs": 2,
#     ".sh": 2
#   }
# }
